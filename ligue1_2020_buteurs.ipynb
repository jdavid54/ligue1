# %%
import requests
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
from bs4 import BeautifulSoup

url = "https://www.ligue1.fr/fr-FR/classement/buteurs"
#j=input('Quelle journee ? (0 pour derniere journee) : ')
#if j:url = "https://www.lfp.fr/ligue1/classement?journee1=0&journee2="+str(j)+"&cat=Gen"

result = requests.get(url, verify=False)
src = result.content


# In[183]:


soup = BeautifulSoup(src, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="fr-FR">
#  <!--<![endif]-->
#  <head>
#   <link href="/-/media/Feature/Experience-Accelerator/Bootstrap/Bootstrap/Styles/optimized-min.css?t=20200129T015528Z" rel="stylesheet"/>
#   <link href="/-/media/Base-Themes/Core-Libraries/styles/optimized-min.css?t=20200129T015533Z" rel="stylesheet"/>
#   <link href="/-/media/Base-Themes/Main-Theme/styles/optimized-min.css?t=20200129T015537Z" rel="stylesheet"/>
#   <link href="/-/media/Themes/LFP/Ligue1/Ligue1/Styles/optimized-min.css?t=20200130T092534Z" rel="stylesheet"/>
#   <meta content="637171839140571097" name="VIcurrentDateTime"/>
#   <script src="/layouts/system/VisitorIdentification.js" type="text/javascript">
#   </script>
#   <script language="javascript" src="/-/Media/Themes/LFP/Site factory/Scripts/jquery-331min.js">
#   </script>
#   <script language="javascript" src="/-/Media/Themes/LFP/Site factory/Scripts/slick-1811min.js">
#   </script>
#   <title>
#    Classement buteurs - Ligue 1 Conforama - LFP
#   </title>
#   <link href="https://fonts.googleapis.com/css?family=Heebo:300,400,700,900" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.6.3/css/all.css" integrity="sha384-UHRtZLI+pbxtHCWp1t77Bi1L4ZtiqrqD80Kn4Z8NTSRyMA2Fd33n5dQ8lWUE00s/" rel="stylesheet"/>
#   <link href="https://www.ligue1.fr:443/-/media/Project/LFP/shared/Images/Competition/Favicon/L1-favicon.jpg" rel="shortcut icon"/>
#   <meta content="Retrouvez le classement des passeurs de la Ligue 1 Conforama et l'historique, sur le site officiel de la Ligue de Football Professionnel." property="og:description"/>
#   <meta content="Ligue1" property="og:site_name"/>
#   <meta content="Classement buteurs - Ligue 1 Conforama - LFP" property="og:title"/>
#   <meta content="https://*/classement/buteurs" property="og:url"/>
#   <link href="https://www.ligue1.fr/fr-FR/classement/buteurs" rel="canonical" season="2019-2020"/>
#   <meta content="Classement buteurs - Ligue 1 Conforama - LFP" name="title"/>
#   <meta content="Retrouvez le classement des buteurs de la Ligue 1 Conforama et l'historique, sur le site officiel de la Ligue de Football Professionnel." name="description"/>
#   <meta content="@Ligue1Conforama" property="twitter:site"/>
#   <meta content="Retrouvez le classement des buteurs de la Ligue 1 Conforama et l'historique, sur le site officiel de la Ligue de Football Professionnel." property="twitter:description"/>
#   <meta content="Classement buteurs - Ligue 1 Conforama - LFP" property="twitter:title"/>
#   <meta content="summary" property="twitter:card"/>
#   <meta content="https://*/classement/buteurs" property="twitter:url"/>
#   <meta content="https://*/classement/buteurs" property="twitter:player"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <script type="text/javascript">
#    var appInsights = window.appInsights || function (a) {
#             function b(a) { c[a] = function () { var b = arguments; c.queue.push(function () { c[a].apply(c, b) }) } } var c = { config: a }, d = document, e = window; setTimeout(function () { var b = d.createElement("script"); b.src = a.url || "https://az416426.vo.msecnd.net/scripts/a/ai.0.js", d.getElementsByTagName("script")[0].parentNode.appendChild(b) }); try { c.cookie = d.cookie } catch (a) { } c.queue = []; for (var f = ["Event", "Exception", "Metric", "PageView", "Trace", "Dependency"]; f.length;)b("track" + f.pop()); if (b("setAuthenticatedUserContext"), b("clearAuthenticatedUserContext"), b("startTrackEvent"), b("stopTrackEvent"), b("startTrackPage"), b("stopTrackPage"), b("flush"), !a.disableExceptionTracking) { f = "onerror", b("_" + f); var g = e[f]; e[f] = function (a, b, d, e, h) { var i = g && g(a, b, d, e, h); return !0 !== i && c["_" + f](a, b, d, e, h), i } } return c
#         }({
#             instrumentationKey:"67bb67cf-4692-4b17-98ef-9ae549eff399"
#         });
#
#         window.appInsights = appInsights, appInsights.queue && 0 === appInsights.queue.length && appInsights.trackPageView();
#
#         var properties = {
#             'Mdp.UserId': '',
#             'Mdp.UserType': '',
#             'Mdp.AppVersion': '',
#             'Mdp.Language': '',
#             'Mdp.ClientId': '',
#             'Mdp.Ticks': '',
#             'Mdp.EventTime': '',
#             'Mdp.EventSequence': 'N.A',
#             'Mdp.ScreenName': '',
#             'Mdp.VideoName': '',
#             'Mdp.VideoId': '',
#             'Mdp.VideoAction': '',
#             'Mdp.VideoSubscriptionId': 'N.A',
#             'Mdp.VideoURL': 'N.A',
#             'Mdp.VideoType': 'N.A',
#             'Mdp.VideoResolution': '',
#             'Mdp.VideoBitrate': '',
#             'Mdp.VideoAutoplay': '',
#             'Mdp.VideoPlayer': '',
#             'Mdp.VideoMinutesFromStart': '',
#             'Mdp.VideoSecondsWatched': '',
#             'Mdp.Custom.ArticleId': '',
#             'Mdp.Custom.CompetitionId': '',
#             'Mdp.Custom.Tags': '',
#             'Mdp.Custom.ScreenType': '',
#             'Mdp.Custom.ScreenUrl': '',
#             'Mdp.Custom.ChannelOfVideo': '',
#             'Mdp.Custom.ProgramOfVideo': '',
#             'Mdp.Custom.PlaylistOfVideo': '',
#             'Mdp.Custom.VideoAccessType': ''
#         };
#
#         // Common event properties
#         properties['Mdp.UserId'] = '';
#         properties['Mdp.UserType'] = 'Guest';
#         properties['Mdp.AppVersion'] = '';
#         properties['Mdp.Language'] = 'fr-FR';
#         properties['Mdp.ClientId'] = '';
#         properties['Mdp.Ticks'] = '637171839140727199';
#         properties['Mdp.EventTime'] = '1581587114';
#
#         // Screenview event properties
#         // in the head section of the page, we get the title
#         properties['Mdp.ScreenName'] = document.title.toString();
#
#         // Video event properties
#         properties['Mdp.VideoName'] = '';
#         //properties['Mdp.VideoId'] = '';
#         properties['Mdp.VideoId'] = '';
#         //properties['Mdp.VideoResolution'] = '';
#         properties['Mdp.VideoBitrate'] = '';
#         properties['Mdp.VideoAutoplay'] = '';
#         properties['Mdp.VideoPlayer'] = '';
#
#         //Article event properties
#         properties['Mdp.Custom.ArticleId'] = '';
#
#         // Additional custom event properties
#         properties['Mdp.Custom.CompetitionId'] = 'D1FR';
#         properties['Mdp.Custom.Tags'] = '';
#
#                 properties['Mdp.Custom.ScreenType'] = 'Ranking';
#
#         properties['Mdp.Custom.ScreenUrl'] = 'https://www.ligue1.fr/fr-FR/classement/buteurs';
#         properties['Mdp.Custom.ChannelOfVideo'] = '';
#         properties['Mdp.Custom.ProgramOfVideo'] = '';
#         properties['Mdp.Custom.PlaylistOfVideo'] = '';
#         properties['Mdp.Custom.VideoAccessType'] = '';
#
#         appInsights.trackEvent("Event properties", properties);
#   </script>
#   <script src="/sitecore%20modules/Web/ExperienceForms/scripts/jquery.validate.min.js">
#   </script>
#   <script src="/sitecore%20modules/Web/ExperienceForms/scripts/jquery.validate.unobtrusive.min.js">
#   </script>
#   <script src="/sitecore%20modules/Web/ExperienceForms/scripts/jquery.unobtrusive-ajax.min.js">
#   </script>
#   <script src="/sitecore%20modules/Web/ExperienceForms/scripts/form.validate.js">
#   </script>
#   <script src="/sitecore%20modules/Web/ExperienceForms/scripts/form.tracking.js">
#   </script>
#  </head>
#  <body class="default-device bodyclass">
#   <!-- #header -->
#   <!-- #wrapper -->
#   <header class="header relative">
#    <div class="" id="header">
#     <div class="component white-bg">
#      <div class="component container relative">
#       <div class="component image desktop-item">
#        <div class="component-content">
#         <div class="logo">
#          <div class="field-headerlogo">
#           <a href="/">
#            <img alt="Ligue1 Logo" data-variantfieldname="HeaderLogo" data-variantitemid="{135D8B46-019F-43D0-AA5C-C449A85CFC4B}" height="414" src="/-/media/Project/LFP/shared/Images/Competition/Logo/L1.jpg?h=414&amp;la=fr-FR&amp;w=300&amp;hash=7B8B9FEF6469D9E0573E995E211CE803" width="300"/>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="component component-scorebar" id="topscorebar">
#        <div class="league">
#         <a href="">
#         </a>
#        </div>
#        <div class="scorebar">
#         <div class="scorebar-controls">
#         </div>
#         <div class="scorebar-inner">
#          <div class="scorebar-items">
#           <span class="strong hidden" id="show_no_data_msg" style="white-space:nowrap;position:absolute;top:50%;transform:translateY(-50%);">
#            Pas de données disponible pour la score bar
#           </span>
#           <div id="is_loading">
#            <i class="fa fa-refresh fa-spin">
#            </i>
#           </div>
#           <div class="scorebar-item">
#            <a href="#">
#             <div class="scorebar-item-date txt-xs uppercase">
#             </div>
#             <div class="scorebar-item-teams">
#              <div class="scorebar-item-team scorebar-item-team-home">
#               <div class="scorebar-item-team-logo">
#               </div>
#               <span class="scorebar-item-team-name">
#               </span>
#               <span class="scorebar-item-team-score right">
#               </span>
#              </div>
#              <div class="scorebar-item-team scorebar-item-team-away">
#               <div class="scorebar-item-team-logo">
#               </div>
#               <span class="scorebar-item-team-name">
#               </span>
#               <span class="scorebar-item-team-score right">
#               </span>
#              </div>
#             </div>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="mobile-item">
#         <a class="score-toggler">
#          <span class="uppercase">
#           scores
#          </span>
#         </a>
#        </div>
#       </div>
#       <script type="text/javascript">
#        document.addEventListener('DOMContentLoaded', function () {
#             SCBAR.icopartpath = 'ligue1';
#             SCBAR.lang = 'fr';
#             SCBAR.run();
#         });
#       </script>
#      </div>
#     </div>
#     <div class="component container float-wrapper">
#      <div class="component image mobile-item">
#       <div class="component-content">
#        <div class="logo">
#         <div class="field-headerlogo">
#          <a href="/">
#           <img alt="Ligue1 Logo" data-variantfieldname="HeaderLogo" data-variantitemid="{135D8B46-019F-43D0-AA5C-C449A85CFC4B}" height="414" src="/-/media/Project/LFP/shared/Images/Competition/Logo/L1.jpg?h=414&amp;la=fr-FR&amp;w=300&amp;hash=7B8B9FEF6469D9E0573E995E211CE803" width="300"/>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <!-- Link List menu -->
#      <div class="component link-list-menu">
#       <div class="menu-btn left">
#        <a data-role="button" data-toggle="menu">
#         <i class="fas fa-bars">
#         </i>
#         <i class="fas fa-times default-hidden">
#         </i>
#        </a>
#       </div>
#       <div class="main-menu">
#        <div class="container">
#         <div class="main-menu-holder">
#          <ul class="main-menu-nav">
#           <li>
#            <img alt="News" class="item-icon" data-variantfieldname="Icon" data-variantitemid="{63AD494E-5BD8-42CA-97F2-98DEB84BF12A}" src="/-/media/Project/LFP/Site-factory/samplepics/Burger-Menu/News.svg?la=fr-FR&amp;hash=F847D70863C9299B81591E2AE63BB16E"/>
#            <a href="/news">
#             News
#            </a>
#           </li>
#           <li>
#            <img alt="" class="item-icon" data-variantfieldname="Icon" data-variantitemid="{1FA4C71B-C338-49E8-957C-A7324CF83A23}" src="/-/media/Project/LFP/Site-factory/samplepics/Burger-Menu/Ligue1TV.svg?la=fr-FR&amp;hash=C5EB9B9C68B602DB9C77EA8C0D7E7001"/>
#            <a href="/tv">
#             Ligue 1 TV
#            </a>
#           </li>
#           <li class="has-arrow">
#            <img alt="" class="item-icon" data-variantfieldname="Icon" data-variantitemid="{8610B80F-84EA-46AD-BF1C-C0434282CC05}" src="/-/media/Project/LFP/Site-factory/samplepics/Burger-Menu/Classements.svg?la=fr-FR&amp;hash=EFDBB5EF7CCD55DF0A93F9EB657DC4DA"/>
#            <a>
#             Classements
#            </a>
#            <ul class="submenu">
#             <li class="field-label">
#              <a href="/classement">
#               Classement Général
#              </a>
#             </li>
#             <li class="field-label">
#              <a href="/classement/buteurs">
#               Classement Buteurs
#              </a>
#             </li>
#             <li class="field-label">
#              <a href="/classement/passeurs">
#               Classement Passeurs
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li>
#            <img alt="" class="item-icon" data-variantfieldname="Icon" data-variantitemid="{4C2F389B-800E-4A61-94F6-68C7FE670711}" height="150" src="/-/media/Project/LFP/Site-factory/samplepics/Burger-Menu/calendriers.png?h=150&amp;la=fr-FR&amp;w=150&amp;hash=E00891EF22BE7951F2C80DDF1FCCE242" width="150"/>
#            <a href="/calendrier-resultats">
#             Calendriers/Résultats
#            </a>
#           </li>
#           <li>
#            <img alt="" class="item-icon" data-variantfieldname="Icon" data-variantitemid="{FFE8AEA1-F7BC-4DB6-B2DD-BCE1D1F634D8}" src="/-/media/Project/LFP/Site-factory/samplepics/Burger-Menu/Clubs.svg?la=fr-FR&amp;hash=23C96CAF2641D9AAB99A0E22DA803164"/>
#            <a href="/clubs/liste">
#             Clubs
#            </a>
#           </li>
#           <li>
#            <img alt="" class="item-icon" data-variantfieldname="Icon" data-variantitemid="{B2374C8B-A61A-437C-B0D1-033CB660B38D}" src="/-/media/Project/LFP/Site-factory/samplepics/Burger-Menu/Joueurs.svg?la=fr-FR&amp;hash=C64090B3D1AC5914691C5E7582F3033B"/>
#            <a href="/listejoueurs">
#             Joueurs
#            </a>
#           </li>
#           <li>
#            <img alt="" class="item-icon" data-variantfieldname="Icon" data-variantitemid="{4D4B0956-00E7-4722-903F-CEB8FB5AE4F7}" src="/-/media/Project/LFP/Site-factory/samplepics/Burger-Menu/Stats-Center.svg?la=fr-FR&amp;hash=B4310689848E9DABA28BD5BCD0C75B9A"/>
#            <a href="/stats">
#             Stats Center
#            </a>
#           </li>
#           <li>
#            <img alt="Transferts" class="item-icon" data-variantfieldname="Icon" data-variantitemid="{86726B6D-4D07-425E-BBF0-067FE1E4E19D}" src="/-/media/Project/LFP/Site-factory/samplepics/Burger-Menu/Transferts.svg?la=fr-FR&amp;hash=A9F4D251C28829F0D3C1E4EEEF5AAADE"/>
#            <a href="/transferts">
#             Transferts
#            </a>
#           </li>
#           <li>
#            <img alt="11-type" class="item-icon" data-variantfieldname="Icon" data-variantitemid="{0C08E8E9-E92E-4A04-8C71-B4DF57BA161E}" src="/-/media/Project/LFP/Site-factory/samplepics/Burger-Menu/BallLogo.svg?la=fr-FR&amp;hash=018C1AB1CD69FFA2061D770660672464"/>
#            <a href="/11-type">
#             11-Type
#            </a>
#           </li>
#           <li>
#            <img alt="" class="item-icon" data-variantfieldname="Icon" data-variantitemid="{6A4A07C1-13E7-48F6-9125-12D77EB10878}" height="150" src="/-/media/Project/LFP/Site-factory/samplepics/Burger-Menu/Presentation.png?h=150&amp;la=fr-FR&amp;w=150&amp;hash=2893E6F29EDA3F09272C95C9626B987B" width="150"/>
#            <a href="https://www.lfp.fr" rel="noopener noreferrer" target="_blank">
#             LFP.FR
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="search">
#       <a class="fas fa-search" style="color: #fff">
#       </a>
#       <div class="search-panel">
#        <div class="search-input">
#         <a class="fas fa-search mobileTest" style="display:none;color: rgb(255, 255, 255);z-index: 0;position: absolute;bottom: 12px;font-size: 18px;">
#         </a>
#         <input id="global-search" type="search"/>
#         <a class="close-search">
#          <i class="fas fa-times">
#          </i>
#         </a>
#        </div>
#        <div class="search-results-container">
#         <div class="search-results-inner">
#         </div>
#        </div>
#       </div>
#      </div>
#      <script>
#      </script>
#      <input id="signForgeryToken" type="hidden" value="jaUVbLGMHeacBsBjxSPc8CA4ACU3mnk0HzArlErW04Zo49sq0pd7bEqD9YPvf6i_9Jqcuil_w7LeRNWcQKmpyQ-MHQJLX1SoER-4VCZLKgc1,QH5gKGVLCjw1Q8QxAjyjFoEY_qPcWIF2HfrjU9aacBLt17W_P4t4kixVrfKR7HRRVxs9GPr4UgA3Ngbu93VvyJb6dBEcKvG8mYav8aNUqdM1"/>
#      <div class="sign right">
#       <a class="myleaguelogo" data-role="button" href="/">
#       </a>
#       <div class="sign-panel container">
#        <section class="sign-up white-bg default-hidden" id="section-signup">
#         <div class="close-modal" data-role="close-modal" id="close-modal" onclick="closeSignModal()">
#          <a>
#           <i class="fas fa-times">
#           </i>
#          </a>
#         </div>
#         <div class="left-section left white-bg">
#          <div class="section-title left-section-title">
#           S'inscrire à
#           <img src="/-/media/Project/LFP/shared/Images/competition/MyLeague_ligue1.png"/>
#          </div>
#          <form action="/api/sitecore/Signup" class="signup-form" id="form-signup" method="post">
#           <input name="__RequestVerificationToken" type="hidden" value="uzB_Bjj1PscPG5XrRvbdcv18V0YVD11HoObmaQj-gaBqs8Uj-RlLcjx8-q6F_ROZfES1fRxZMC_4YbsAI_5MOP-ZnACGGOTj4C2ouwhcpM41"/>
#           <div class="form-group">
#            <label for="signupName">
#             Prenom*
#            </label>
#            <input id="Name" name="Name" type="text" value=""/>
#            <div class="error-zone">
#             <label class="form-error" id="error-Name">
#              Ce champ est obligatoire
#             </label>
#            </div>
#           </div>
#           <div class="form-group">
#            <label for="signupLastName">
#             Nom*
#            </label>
#            <input id="Surname" name="Surname" type="text" value=""/>
#            <div class="error-zone">
#             <label class="form-error" id="error-Surname">
#              Ce champ est obligatoire
#             </label>
#            </div>
#           </div>
#           <div class="form-group password_main_div">
#            <label for="signupPass">
#             Mot de passe*
#            </label>
#            <input id="NewPassword" name="NewPassword" type="password"/>
#            <div class="password_constraint" id="signup_password_constraint">
#             <label>
#              Le mot de passe doit respecter un minimum de
#             </label>
#             <ul>
#              <li class="invalid" id="signup_password_constraint_length">
#               Min. 8 caractères
#              </li>
#              <li class="invalid" id="signup_password_constraint_uppercase">
#               Au moins une majuscule
#              </li>
#              <li class="invalid" id="signup_password_constraint_lowercase">
#               Au moins une minuscule
#              </li>
#              <li class="invalid" id="signup_password_constraint_special">
#               Au moins un caractère spécial
#              </li>
#              <li class="invalid" id="signup_password_constraint_number">
#               Au moins un chiffre
#              </li>
#             </ul>
#            </div>
#            <div class="error-zone">
#             <label class="form-error" id="error-NewPassword">
#              Ce champ est obligatoire
#             </label>
#            </div>
#           </div>
#           <div class="form-group">
#            <label for="signupEmail">
#             Email*
#            </label>
#            <input id="Mail" name="Mail" type="text" value=""/>
#            <div class="error-zone">
#             <label class="form-error" id="error-Mail">
#              Ce champ est obligatoire
#             </label>
#             <label class="form-error" id="error-DuplicateMail">
#              Cet email est déjà utilisé
#             </label>
#            </div>
#           </div>
#           <div class="form-group">
#            <label for="signupClub">
#             Club de coeur*
#            </label>
#            <select id="SelectedTeam" name="SelectedTeam">
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/18.png" value="18">
#              AMIENS SC
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/37.png" value="37">
#              ANGERS SCO
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9.png" value="9">
#              AS MONACO
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/31.png" value="31">
#              AS SAINT-ÉTIENNE
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/74.png" value="74">
#              DIJON FCO
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/4.png" value="4">
#              FC GIRONDINS DE BORDEAUX
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/8.png" value="8">
#              FC METZ
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/12.png" value="12">
#              FC NANTES
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/158.png" value="158">
#              LOSC LILLE
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/10.png" value="10">
#              MONTPELLIER HÉRAULT SC
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/27.png" value="27">
#              NÎMES OLYMPIQUE
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/30.png" value="30">
#              OGC NICE
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/1.png" value="1">
#              OLYMPIQUE DE MARSEILLE
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/159.png" value="159">
#              OLYMPIQUE LYONNAIS
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/13.png" value="13">
#              PARIS SAINT-GERMAIN
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/15.png" value="15">
#              RC STRASBOURG ALSACE
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/44.png" value="44">
#              STADE BRESTOIS 29
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/41.png" value="41">
#              STADE DE REIMS
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/14.png" value="14">
#              STADE RENNAIS FC
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/16.png" value="16">
#              TOULOUSE FC
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/17.png" value="17">
#              AC AJACCIO
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/2.png" value="2">
#              AJ AUXERRE
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/11.png" value="11">
#              AS NANCY LORRAINE
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/28.png" value="28">
#              CHAMOIS NIORTAIS FC
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/22.png" value="22">
#              CHÂTEAUROUX
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/40.png" value="40">
#              CLERMONT FOOT 63
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/24.png" value="24">
#              EN AVANT GUINGAMP
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/33.png" value="33">
#              ESTAC TROYES
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9443.png" value="9443">
#              FC CHAMBLY OISE
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/7.png" value="7">
#              FC LORIENT
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/160.png" value="160">
#              FC SOCHAUX-MONTBÉLIARD
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/38.png" value="38">
#              GRENOBLE FOOT 38
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/5.png" value="5">
#              HAVRE AC
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/26.png" value="26">
#              LE MANS FC
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/90.png" value="90">
#              PARIS FC
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/6.png" value="6">
#              RC LENS
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/64.png" value="64">
#              RODEZ AVEYRON FOOTBALL
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/20.png" value="20">
#              STADE MALHERBE CAEN
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/58.png" value="58">
#              US ORLÉANS
#             </option>
#             <option data-imagesrc="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/68.png" value="68">
#              VALENCIENNES FC
#             </option>
#            </select>
#            <input id="SelectedTeamValue" name="SelectedTeamValue" type="hidden" value=""/>
#            <div class="error-zone">
#             <label class="form-error" id="error-SelectedTeam">
#              Ce champ est obligatoire
#             </label>
#            </div>
#           </div>
#           <div class="form-group">
#            <label for="signupConfirmPass">
#             Confirmation de mot de passe*
#            </label>
#            <input id="RepeatPassword" name="RepeatPassword" type="password"/>
#            <div class="error-zone">
#             <label class="form-error" id="error-RepeatPasswordRequired">
#              Ce champ est obligatoire
#             </label>
#             <label class="form-error" id="error-RepeatPassword">
#              Les mots de passe ne correspondent pas
#             </label>
#            </div>
#           </div>
#           <div class="form-line">
#            <div class="form-optin">
#             <input id="IsCompetitionChecked" name="IsCompetitionChecked" type="checkbox" value="true"/>
#             <input name="IsCompetitionChecked" type="hidden" value="false"/>
#             J'accepte de recevoir des informations sur les compétitions organisées par la LFP.
#            </div>
#           </div>
#           <div class="form-line">
#            <div class="form-optin">
#             <input id="IsPartnersChecked" name="IsPartnersChecked" type="checkbox" value="true"/>
#             <input name="IsPartnersChecked" type="hidden" value="false"/>
#             J’accepte de recevoir des informations de la part des partenaires commerciaux de la LFP.
#            </div>
#           </div>
#           <div class="form-line">
#            <div class="form-optin">
#             <input id="IsTOSChecked" name="IsTOSChecked" type="checkbox" value="true"/>
#             <input name="IsTOSChecked" type="hidden" value="false"/>
#             Je reconnais avoir lu et accepté les
#             <a href="/fr-FR/myligue/cgu" target="_blank">
#              conditions générales d'utilisation
#             </a>
#             et la politique de confidentialité
#             <label class="form-error" id="error-IsTOSChecked">
#              Ce champ est obligatoire
#             </label>
#            </div>
#           </div>
#           <div class="form-line">
#            <div class="form-group">
#             <div>
#              <div class="g-recaptcha" data-sitekey="6Lc1O40UAAAAAOInfkRkYk_0b9-94NsxEXXYiST7">
#              </div>
#              <div>
#               <label class="form-error" id="error-IsCaptchaValid">
#                Ce champ est obligatoire
#               </label>
#              </div>
#             </div>
#            </div>
#            <div class="form-group form-group-signup-confirmation">
#             <div>
#              <button class="button button-submit button-center" id="btnSignup" type="submit">
#               S'inscrire
#               <i id="spinSignup">
#               </i>
#              </button>
#             </div>
#             <div>
#              <label class="form-error" id="error-TechnicalError">
#               Une erreur technique est survenue, merci de réessayer ultérieurement
#              </label>
#              <label class="form-message" id="message-LblMailSend">
#               Un email de confirmation a été envoyé. Veuillez cliquer sur le lien pour terminer votre inscription.
#              </label>
#             </div>
#            </div>
#           </div>
#           <div class="form-line" id="pdi">
#            <label>
#            </label>
#            <label>
#             ...
#            </label>
#            <a onclick="show()">
#             Lire la suite
#            </a>
#           </div>
#           <div class="form-line hidden-zone" id="pda">
#            <label>
#             Vos données personnelles sont traitées par la Ligue de Football Professionnel (association loi 1901, siège social 6, Rue Léo Delibes 75116 Paris - LFP) pour les finalités et sur les bases juridiques suivantes : Gestion de votre inscription et de votre compte : l’exécution des CGU applicables au Site ; l’envoi de communications personnalisées et la transmission aux partenaires pour l’envoi de communication et offres : votre consentement ; afin de répondre à des demandes de contact, l’envoi d’information généralisées de la part de la LFP, permettre l’amélioration du Site et la réalisation d’études statistiques : l’intérêt légitime de la LFP d’assurer le suivi des demandes et réponses (hors exercice des droits sur les données) mais également de promouvoir son activité et améliorer ses Sites et supports de communication ; ou encore pour répondre aux demandes d’exercice de droit sur les données personnelles : répondre à une obligation légale de la LFP en tant que responsable du traitement. Les données peuvent être transmises par la LFP à ses prestataires techniques, à ses partenaires lorsque vous y avez consenti, aux services internes de la LFP.
# La LFP a désigné un DPO que vous pouvez contacter par courrier à l'attention du DPO de la LFP - 6 Rue Léo Delibes 75116 ou dans le cadre de l’exercice de vos droits, via le formulaire d’exercice des droits.
# Pour en savoir plus sur le traitement de vos données et sur vos droits, consultez l’ Information sur la Protection des données personnelles.
#            </label>
#           </div>
#          </form>
#          <div class="form-line">
#           <label class="right">
#            *Champs obligatoires
#           </label>
#          </div>
#         </div>
#         <script async="" defer="" src="https://www.google.com/recaptcha/api.js">
#         </script>
#         <script src="/-/media/Themes/LFP/Site factory/Scripts/ddslick.js">
#         </script>
#         <script>
#          $(function () {
#             ManageAjaxCall('#btnSignup', otherButtonID = '', popupID = '', formAction = '', '#signForgeryToken', '#spinSignup', '#form-signup', true);
#             ValidatePassword('#NewPassword', '#signup_password_constraint', '#signup_password_constraint_length', '#signup_password_constraint_uppercase', '#signup_password_constraint_lowercase', '#signup_password_constraint_number', '#signup_password_constraint_special', '#error-NewPassword');
#         });
#
#         $('#SelectedTeam').ddslick({
#             onSelected: function (selectedData) {
#                 $('#SelectedTeamValue').val(selectedData.selectedData.value);
#             }
#         });
#
#         function show() {
#             $('#pdi').css({ display: 'none' });
#             $('#pda').css({ display: 'block' });
#         }
#         </script>
#        </section>
#        <section class="sign-in main-bg" id="section-signin">
#         <form action="/api/sitecore/Signin" class="login-form" id="form-signin" method="post">
#          <input name="__RequestVerificationToken" type="hidden" value="efC28IxTZ_xAjGxUIcUP3ywCrTzVnRO5-TyLo7MMNFusD7QY5bfyT1VzAaezse2dEssocF04M_nGdfdxmX1195zIhDrHE4mbRWrQ9t9Yfko1"/>
#          <div class="sign-modal" id="sign-modal">
#           <div class="centered form-line">
#            Les
#            <a href="/fr-FR/myligue/cgu" target="_blank">
#             CGU
#            </a>
#            ont changés
#           </div>
#           <div class="centered">
#            <button class="button button-primary" id="btnAccept" type="submit">
#             Accepter
#             <i id="spinTOSAccepted">
#             </i>
#            </button>
#            <button class="button button-primary" id="btnDecline" type="submit">
#             Decliner
#             <i id="spinTOSDeclined">
#             </i>
#            </button>
#           </div>
#          </div>
#          <input id="IsReload" name="IsReload" type="hidden" value="False"/>
#          <div class="close-modal" data-role="close-modal" id="close-modal" onclick="closeSignModal()">
#           <a>
#            <i class="fas fa-times">
#            </i>
#           </a>
#          </div>
#          <div class="right-section right secondary-bg">
#           <div class="section-title right-section-title">
#            identifiez-vous à
#            <img src="/-/media/Project/LFP/shared/Images/competition/MyLeague_ligue1.png"/>
#           </div>
#           <div class="form-group">
#            <label for="loginName">
#             IDENTIFIANT *
#            </label>
#            <input id="Login" name="Login" type="text" value=""/>
#            <label class="form-error" id="error-Surname">
#             Champ obligatoire
#            </label>
#           </div>
#           <div class="form-group">
#            <label for="loginPass">
#             Mot de passe*
#            </label>
#            <input id="CurrentPassword" name="CurrentPassword" type="password"/>
#            <label class="form-error" id="error-CurrentPassword">
#             Champ obligatoire
#            </label>
#           </div>
#           <div class="form-group">
#            <label class="form-error" id="error-MailValidation">
#             Votre identifiant ou votre mot de passe n'est pas valide.
#            </label>
#            <label class="form-error" id="error-Account">
#             Votre identifiant ou votre mot de passe n’est pas valide.
#            </label>
#           </div>
#           <div class="centered">
#            <button class="button button-primary" id="btnIndex" type="submit">
#             S'IDENTIFIER
#             <i id="spinSignin">
#             </i>
#            </button>
#           </div>
#           <div>
#           </div>
#           <input id="resetPasswordUrl" type="hidden" value="/ResetPassword"/>
#           <div class="form-line centered">
#            <a class="centered link" id="alink_resetpassword">
#             Mot de passe oublié ?
#            </a>
#           </div>
#           <div class="main-bg p-20">
#            <div class="section-title secondary-title">
#             pas encore membre ?
#            </div>
#            <div class="centered">
#             <a class="button button-narrow button-secondary" data-target="sign-up" id="btnCreateAccount">
#              créer mon compte
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="left-section left white-bg">
#           <div class="section-title left-section-title">
#            découvrez
#            <img src="/-/media/Project/LFP/shared/Images/competition/MyLeague_ligue1.png"/>
#           </div>
#           <div class="video-player" style="text-align:center">
#            <iframe allowfullscreen="" frameborder="0" height="324" src="//player.ooyala.com/static/v4/production/skin-plugin/iframe.html?ec=ZlancyajE6l7UE5cVpy0Q6hwD5aLGMu9&amp;pbid=4fdcfe1e33d94fc9920a4b68cc305b31&amp;pcode=VueW0yOmsQiA5dtCfbb2EzriIGB_" width="575">
#            </iframe>
#           </div>
#           <div class="signup-links">
#            <ul>
#             <li>
#              <a class="not-active">
#               <div class="link-image">
#                <img src="/-/media/Project/LFP/Site-factory/SigninLinks/star.png"/>
#               </div>
#               <div class="link-title">
#                Profitez gratuitement
#               </div>
#               <div class="link-subtitle">
#                de contenus exclusifs
#               </div>
#              </a>
#             </li>
#             <li>
#              <a class="not-active">
#               <div class="link-image">
#                <img src="/-/media/Project/LFP/Site-factory/SigninLinks/heart.png"/>
#               </div>
#               <div class="link-title">
#                Personnalisez
#               </div>
#               <div class="link-subtitle">
#                votre expérience web selon votre club de coeur et vos joueurs favoris
#               </div>
#              </a>
#             </li>
#             <li>
#              <a class="not-active">
#               <div class="link-image">
#                <img src="/-/media/Project/LFP/Site-factory/SigninLinks/download.png"/>
#               </div>
#               <div class="link-title">
#                Sauvegardez
#               </div>
#               <div class="link-subtitle">
#                les contenus pour plus tard
#               </div>
#              </a>
#             </li>
#             <li>
#              <a class="not-active">
#               <div class="link-image">
#                <img src="/-/media/Project/LFP/Site-factory/SigninLinks/envelope.png"/>
#               </div>
#               <div class="link-title">
#                Ne ratez rien
#               </div>
#               <div class="link-subtitle">
#                de la compétition en recevant l'actualité de la compétition par email
#               </div>
#              </a>
#             </li>
#             <li>
#              <a class="not-active">
#               <div class="link-image">
#                <img src="/-/media/Project/LFP/Site-factory/SigninLinks/warning.png"/>
#               </div>
#               <div class="link-title">
#                Retrouvez
#               </div>
#               <div class="link-subtitle">
#                l'intégralité des statistiques de la compétition
#               </div>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <script>
#           $(function () {
#                 ManageAjaxCall('#btnAccept', '#btnDecline', '', 'Accept', '#signForgeryToken', '#spinTOSAccepted', '#form-signin', false);
#                 ManageAjaxCall('#btnDecline', '#btnAccept', '', 'Decline', '#signForgeryToken', '#spinTOSDeclined', '#form-signin', false);
#                 ManageAjaxCall('#btnIndex', '#btnCreateAccount', '#sign-modal', 'Index', '#signForgeryToken', '#spinSignin', '#form-signin', false);
#
#                 $('#alink_resetpassword').click(function (event) {
#                     var baseUrl = $('#resetPasswordUrl').val();
#                     baseUrl += "?email=" + $('#Login').val();
#                     window.location.href = baseUrl;
#                 });
#             });
#          </script>
#         </form>
#        </section>
#       </div>
#      </div>
#     </div>
#    </div>
#   </header>
#   <!-- /#header -->
#   <!-- #content -->
#   <main>
#    <div class="component hero-container small-hero-container">
#     <div class="component">
#      <div class="hero">
#       <div class="hero-image">
#        <picture>
#         <img alt="LFP" data-variantfieldname="BannerImage" data-variantitemid="{CFBDFD78-0479-49E3-B91A-D8159BB98A3D}" height="280" src="/-/media/Project/LFP/shared/Default_image_header.jpg?h=280&amp;la=fr-FR&amp;w=1440&amp;hash=96DD3801D2EA383C478FD6346BEED2D3" width="1440"/>
#         <source media="(max-width: 768px)" srcset="/-/media/Project/LFP/shared/Default_image_header_mob.jpg?la=fr-FR"/>
#        </picture>
#       </div>
#       <div class="hero-details">
#        <div class="subtitle uppercase field-abstract">
#        </div>
#        <h1 class="field-title">
#         Classement buteurs
#        </h1>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="component">
#     <div class="tabulation">
#      <div class="container component">
#       <div class="tabulation-Container">
#        <ul class="tabulation-List">
#         <li class="tabulation-ListItem" tabindex="-1">
#          <a class="tabulation-ListItemLink" href="/fr-FR/classement">
#           Général
#          </a>
#         </li>
#         <li class="tabulation-ListItem active" tabindex="0">
#          <a class="tabulation-ListItemLink" href="/fr-FR/classement/buteurs">
#           Buteurs
#          </a>
#         </li>
#         <li class="tabulation-ListItem" tabindex="-1">
#          <a class="tabulation-ListItemLink" href="/fr-FR/classement/passeurs">
#           Passeurs
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="container">
#      <div class="component">
#       <div class="filters main-bg distance-around">
#        <div class="mobile-item">
#         <a class="filter-expander">
#          Filtres
#          <i class="fas fa-chevron-right">
#          </i>
#         </a>
#        </div>
#        <form>
#         <div class="custom-dropdown ranking-page-filter">
#          <label class="uppercase">
#           SAISON
#          </label>
#          <select id="CompetitionRankingPage_SelectSeasons" name="seasonId">
#           <option value="1932-1933">
#            1932/1933
#           </option>
#           <option value="1933-1934">
#            1933/1934
#           </option>
#           <option value="1934-1935">
#            1934/1935
#           </option>
#           <option value="1935-1936">
#            1935/1936
#           </option>
#           <option value="1936-1937">
#            1936/1937
#           </option>
#           <option value="1937-1938">
#            1937/1938
#           </option>
#           <option value="1938-1939">
#            1938/1939
#           </option>
#           <option value="1939-1940">
#            1939/1940
#           </option>
#           <option value="1940-1941">
#            1940/1941
#           </option>
#           <option value="1941-1942">
#            1941/1942
#           </option>
#           <option value="1942-1943">
#            1942/1943
#           </option>
#           <option value="1943-1944">
#            1943/1944
#           </option>
#           <option value="1944-1945">
#            1944/1945
#           </option>
#           <option value="1945-1946">
#            1945/1946
#           </option>
#           <option value="1946-1947">
#            1946/1947
#           </option>
#           <option value="1947-1948">
#            1947/1948
#           </option>
#           <option value="1948-1949">
#            1948/1949
#           </option>
#           <option value="1949-1950">
#            1949/1950
#           </option>
#           <option value="1950-1951">
#            1950/1951
#           </option>
#           <option value="1951-1952">
#            1951/1952
#           </option>
#           <option value="1952-1953">
#            1952/1953
#           </option>
#           <option value="1953-1954">
#            1953/1954
#           </option>
#           <option value="1954-1955">
#            1954/1955
#           </option>
#           <option value="1955-1956">
#            1955/1956
#           </option>
#           <option value="1956-1957">
#            1956/1957
#           </option>
#           <option value="1957-1958">
#            1957/1958
#           </option>
#           <option value="1958-1959">
#            1958/1959
#           </option>
#           <option value="1959-1960">
#            1959/1960
#           </option>
#           <option value="1960-1961">
#            1960/1961
#           </option>
#           <option value="1961-1962">
#            1961/1962
#           </option>
#           <option value="1962-1963">
#            1962/1963
#           </option>
#           <option value="1963-1964">
#            1963/1964
#           </option>
#           <option value="1964-1965">
#            1964/1965
#           </option>
#           <option value="1965-1966">
#            1965/1966
#           </option>
#           <option value="1966-1967">
#            1966/1967
#           </option>
#           <option value="1967-1968">
#            1967/1968
#           </option>
#           <option value="1968-1969">
#            1968/1969
#           </option>
#           <option value="1969-1970">
#            1969/1970
#           </option>
#           <option value="1970-1971">
#            1970/1971
#           </option>
#           <option value="1971-1972">
#            1971/1972
#           </option>
#           <option value="1972-1973">
#            1972/1973
#           </option>
#           <option value="1973-1974">
#            1973/1974
#           </option>
#           <option value="1974-1975">
#            1974/1975
#           </option>
#           <option value="1975-1976">
#            1975/1976
#           </option>
#           <option value="1976-1977">
#            1976/1977
#           </option>
#           <option value="1977-1978">
#            1977/1978
#           </option>
#           <option value="1978-1979">
#            1978/1979
#           </option>
#           <option value="1979-1980">
#            1979/1980
#           </option>
#           <option value="1980-1981">
#            1980/1981
#           </option>
#           <option value="1981-1982">
#            1981/1982
#           </option>
#           <option value="1982-1983">
#            1982/1983
#           </option>
#           <option value="1983-1984">
#            1983/1984
#           </option>
#           <option value="1984-1985">
#            1984/1985
#           </option>
#           <option value="1985-1986">
#            1985/1986
#           </option>
#           <option value="1986-1987">
#            1986/1987
#           </option>
#           <option value="1987-1988">
#            1987/1988
#           </option>
#           <option value="1988-1989">
#            1988/1989
#           </option>
#           <option value="1989-1990">
#            1989/1990
#           </option>
#           <option value="1990-1991">
#            1990/1991
#           </option>
#           <option value="1991-1992">
#            1991/1992
#           </option>
#           <option value="1992-1993">
#            1992/1993
#           </option>
#           <option value="1993-1994">
#            1993/1994
#           </option>
#           <option value="1994-1995">
#            1994/1995
#           </option>
#           <option value="1995-1996">
#            1995/1996
#           </option>
#           <option value="1996-1997">
#            1996/1997
#           </option>
#           <option value="1997-1998">
#            1997/1998
#           </option>
#           <option value="1998-1999">
#            1998/1999
#           </option>
#           <option value="1999-2000">
#            1999/2000
#           </option>
#           <option value="2000-2001">
#            2000/2001
#           </option>
#           <option value="2001-2002">
#            2001/2002
#           </option>
#           <option value="2002-2003">
#            2002/2003
#           </option>
#           <option value="2003-2004">
#            2003/2004
#           </option>
#           <option value="2004-2005">
#            2004/2005
#           </option>
#           <option value="2005-2006">
#            2005/2006
#           </option>
#           <option value="2006-2007">
#            2006/2007
#           </option>
# ...
#
#                                     // console.log(kv.Value);
#
#                                     //Show Error
#                                     $('#error_section_horizontal-widget_6d2b1053148d46e39d0c8ea0f7f48fa1').html(kv.Value);
#                                     $('#error_section_horizontal-widget_6d2b1053148d46e39d0c8ea0f7f48fa1').show();
#
#                                     closeNewsletterModel_6d2b1053148d46e39d0c8ea0f7f48fa1();
#                                 }
#                             });
#
#                             // reload captcha
#                             if (reloadCaptcha) {
#                                 grecaptcha.reset(widgetId_6d2b1053148d46e39d0c8ea0f7f48fa1);
#                             }
#                         }).fail(function () {
#                             $('#error_section_horizontal-widget_6d2b1053148d46e39d0c8ea0f7f48fa1').html("Une erreur technique est survenue, merci de r&#233;essayer ult&#233;rieurement");
#                             $('#error_section_horizontal-widget_6d2b1053148d46e39d0c8ea0f7f48fa1').show();
#                             $("#newsletter-popin-id-horizontal-widget_6d2b1053148d46e39d0c8ea0f7f48fa1").hide();
#
#
#                             closeNewsletterModel_6d2b1053148d46e39d0c8ea0f7f48fa1();
#                         });
#                 });
#
#
#                 // click to show popUp
#                 $("#newsletter-btn-horizontal-widget_6d2b1053148d46e39d0c8ea0f7f48fa1").click(function () {
#
#                     var isAuthenticated = false;
#
#                     $('#error_section_horizontal-widget_6d2b1053148d46e39d0c8ea0f7f48fa1').text("");
#                     $('#error_section_horizontal-widget_6d2b1053148d46e39d0c8ea0f7f48fa1').hide();
#
#
#                     //validate email
#                     var emailVal = $("#newsletter-id-horizontal-widget_6d2b1053148d46e39d0c8ea0f7f48fa1 input").val();
#
#                     var isValid = validateEmail(emailVal);
#                     if (isValid || isAuthenticated) {
#                         // console.log("Show captcha popup");
#                         grecaptcha.reset(widgetId_6d2b1053148d46e39d0c8ea0f7f48fa1);
#                         $("#close-modal_nws_6d2b1053148d46e39d0c8ea0f7f48fa1").removeClass('hidden').addClass("modal-backdrop fade in");
#
#                         $("#newsletter-popin-id-horizontal-widget_6d2b1053148d46e39d0c8ea0f7f48fa1").show();
#                     }
#                     else {
#                         $('#error_section_horizontal-widget_6d2b1053148d46e39d0c8ea0f7f48fa1').html("Le format de l&#39;email est incorrect");
#                         $('#error_section_horizontal-widget_6d2b1053148d46e39d0c8ea0f7f48fa1').show();
#                     }
#                 });
#
#                 // click to hide popup
#                 $("#newsletter-popin-id-horizontal-widget_6d2b1053148d46e39d0c8ea0f7f48fa1 #id_hide_popup").click(closeNewsletterModel_6d2b1053148d46e39d0c8ea0f7f48fa1);
#
#                 $("#close-modal_nws_6d2b1053148d46e39d0c8ea0f7f48fa1").click(function () {
#                     //event.stopPropagation();
#                     closeNewsletterModel_6d2b1053148d46e39d0c8ea0f7f48fa1();
#                 });
#
#                 function closeNewsletterModel_6d2b1053148d46e39d0c8ea0f7f48fa1() {
#
#                     $("#close-modal_nws_6d2b1053148d46e39d0c8ea0f7f48fa1").addClass('hidden').removeClass("modal-backdrop fade in");
#                     $("#newsletter-popin-id-horizontal-widget_6d2b1053148d46e39d0c8ea0f7f48fa1").hide();
#                 }
#         });
#          </script>
#         </form>
#        </div>
#       </div>
#      </div>
#      <div class="lighter-bg container-fluid">
#       <div class="row">
#        <div class="component lighter-bg footer-line container">
#         <div class="component">
#          <div class="component left">
#           <!--<div class="component rich-text-light">-->
#           <div class="link-with-image-widget left">
#            <div class="title important uppercase left field-text">
#             <div class="link-title uppercase left">
#              TÉLÉCHARGEZ
#             </div>
#            </div>
#           </div>
#           <!--</div>-->
#           <div class="component link-nodiv link-with-image-widget left js-imgToSvg" id="myLigueFooter">
#            <div class="title uppercase left field-label">
#             LE CALENDRIER
#            </div>
#            <a href="https://www.ligue1.fr/api/sitecore/MatchIcs/Download">
#             <img alt="Calendrier général de la Ligue 1" data-variantfieldname="Icon" data-variantitemid="{E84092B2-5384-421C-809E-A988C9153B5E}" src="/-/media/Project/LFP/shared/Images/Application/calendar-logo-L1.svg?la=fr-FR&amp;hash=1BB5F8A82E82649FC0A03E002C1FC922"/>
#            </a>
#           </div>
#           <div class="social-widget left">
#            <div class="title uppercase left">
#             Suivez nous sur
#            </div>
#            <div class="icons left">
#             <a href="https://twitter.com/ligue1conforama" target="_blank">
#              <i class="fab fa-twitter">
#              </i>
#             </a>
#             <a href="https://fr-fr.facebook.com/Ligue1Conforama/" target="_blank">
#              <i class="fab fa-facebook-f">
#              </i>
#             </a>
#             <a href="https://www.instagram.com/ligue1conforama/?hl=fr" target="_blank">
#              <i class="fab fa-instagram">
#              </i>
#             </a>
#             <a href="https://www.youtube.com/channel/UCQsH5XtIc9hONE1BQjucM0g" target="_blank">
#              <i class="fab fa-youtube">
#              </i>
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="component right">
#           <div class="component border-left left">
#            <div class="component link-nodiv link-with-image-widget left">
#             <div class="field-logo">
#              <a href="http://www.dominosligue2.fr" rel="noopener noreferrer" target="_blank">
#               <img alt="Ligue2 Logo Mono" data-variantfieldname="Logo" data-variantitemid="{8613841B-5000-4CDB-A70D-DC276AD6134B}" height="46" src="/-/media/Project/LFP/shared/Images/Competition/Footer/logo-footer-ligue2.png?h=46&amp;la=fr-FR&amp;w=30&amp;hash=F62C3B61924932FCF433A2EA6FFB4D40" width="30"/>
#              </a>
#             </div>
#            </div>
#            <div class="component link-nodiv link-with-image-widget left">
#             <div class="field-logo">
#              <a href="https://www.coupedelaligue.fr" rel="noopener noreferrer" target="_blank">
#               <img alt="Coupedelaligue Logo Mono" data-variantfieldname="Logo" data-variantitemid="{61DF6071-B06E-494F-8688-BCF47982A1E6}" height="46" src="/-/media/Project/LFP/shared/Images/Competition/Footer/logo-footer-coupedelaligue.png?h=46&amp;la=fr-FR&amp;w=30&amp;hash=03D2046DE4B2BF913CD0A4B5FBB9EBC5" width="30"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="component column-splitter">
#           <div class="component link-list-fulldiv">
#            <div class="component-content">
#             <!--<ul class="main-menu-nav">-->
#             <div class="column" data-width="25">
#              <div class="partners-card">
#               <div>
#                <div class="title uppercase field-label">
#                 Diffuseurs officiels
#                </div>
#                <div class="logos">
#                 <a href="https://www.beinsports.com/france/">
#                  <img alt="Logo BeIN Sports" data-variantfieldname="Logo" data-variantitemid="{385CA87B-E642-4A67-AFAF-821D94C8928D}" height="38" src="/-/media/Project/LFP/shared/Images/Broadcasters/Logo_beIN_SPORTS.png?h=38&amp;la=fr-FR&amp;w=125&amp;hash=EF6654832D8E5EA28AA95E91CED3BF65" width="125"/>
#                 </a>
#                 <a href="https://www.mycanal.fr/sport/">
#                  <img alt="Logo Canal+" data-variantfieldname="Logo" data-variantitemid="{3B5C7773-3B0E-40B1-BA33-7CF62D3EEFB6}" height="31" src="/-/media/Project/LFP/shared/Images/Broadcasters/Canal.png?h=31&amp;la=fr-FR&amp;w=125&amp;hash=FC63F59EED2C61399E181A7853062A9C" width="125"/>
#                 </a>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="column" data-width="25">
#              <div class="partners-card">
#               <div>
#                <div class="title uppercase field-label">
#                 Partenaire Titre
#                </div>
#                <div class="logos">
#                 <a href="https://www.conforama.fr/">
#                  <img alt="Conforama" data-variantfieldname="Logo" data-variantitemid="{1F4A3B07-93B0-464F-8DCF-A472B593C51F}" height="20" src="/-/media/Project/LFP/shared/Images/Partners/logo-conforama.png?h=20&amp;la=fr-FR&amp;w=126&amp;hash=15229DFB3BFCE35E699B188C94652DE2" width="126"/>
#                 </a>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="column" data-width="25">
#              <div class="partners-card">
#               <div>
#                <div class="title uppercase field-label">
#                 Partenaires Officiels
#                </div>
#                <div class="logos">
#                 <a href="https://www.ubereats.com/fr-FR/">
#                  <img alt="Uber Eats" data-variantfieldname="Logo" data-variantitemid="{6B796EC5-25F9-4D7A-9D52-6D29662DC5E0}" height="21" src="/-/media/Project/LFP/shared/Images/Partners/ubereats-landscape.png?h=21&amp;la=fr-FR&amp;w=125&amp;hash=37446E7EE6810CB913E0624EB57064F4" width="125"/>
#                 </a>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="column" data-width="25">
#              <div class="partners-card">
#               <div>
#                <div class="title uppercase field-label">
#                 Voiture Officielle
#                </div>
#                <div class="logos">
#                 <a href="https://www.fiat.fr/berline-fiat-tipo">
#                  <img alt="FIAT Tipo" data-variantfieldname="Logo" data-variantitemid="{701CD40B-9B33-4D2F-8D30-922D2B47C0F8}" height="40" src="/-/media/Project/LFP/shared/Images/Partners/Logo-Fiat-Tipo-Noir.png?h=40&amp;la=fr-FR&amp;w=41&amp;hash=F03C6646EE28470D426A4477B90BFFB6" width="41"/>
#                 </a>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="column" data-width="25">
#              <div class="partners-card">
#               <div>
#                <div class="title uppercase field-label">
#                 Chronométreur officiel
#                </div>
#                <div class="logos">
#                 <a href="https://www.tagheuer.com/fr">
#                  <img alt="Tag HEUER" data-variantfieldname="Logo" data-variantitemid="{F7A79B2E-6868-413B-982F-C1F8B694D64F}" height="20" src="/-/media/Project/LFP/shared/Images/Partners/New-logo-TAG-Heuer.png?h=20&amp;la=fr-FR&amp;w=125&amp;hash=C88808CC6AC5D6647BAEB6A1F283FD11" width="125"/>
#                 </a>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="column" data-width="25">
#              <div class="partners-card">
#               <div>
#                <div class="title uppercase field-label">
#                 Fournisseurs Officiels
#                </div>
#                <div class="logos">
#                 <a href="https://www.laposte.fr/">
#                  <img alt="La Poste" data-variantfieldname="Logo" data-variantitemid="{63C4D351-6167-4082-96B2-AFAADFBDB751}" height="40" src="/-/media/Project/LFP/shared/Images/Partners/logoLP_RVB.png?h=40&amp;la=fr-FR&amp;w=44&amp;hash=E1357339B5AE21531BFB7916E7EF1F0B" width="44"/>
#                 </a>
#                 <a href="https://www.uhlsport.com/fr/">
#                  <img alt="UHLsport" data-variantfieldname="Logo" data-variantitemid="{E7DA839A-86F9-460E-A722-A42E25FED0A8}" height="40" src="/-/media/Project/LFP/shared/Images/Partners/Uhlsport.png?h=40&amp;la=fr-FR&amp;w=31&amp;hash=E98CB9D6355EF92E018FFD7B6FED5ADC" width="31"/>
#                 </a>
#                </div>
#               </div>
#              </div>
#             </div>
#             <!--</ul>-->
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="container-fluid">
#       <div class="row">
#        <div class="component footer-line main-bg container">
#         <div class="component">
#          <div class="component link-list-nodiv links">
#           <ul>
#            <li class="item0 odd first">
#             <span class="field-label">
#              Copyright LFP 2020
#             </span>
#            </li>
#            <li class="item1 even">
#             <span class="field-label">
#              <a href="/mentions-legales">
#               Mentions légales
#              </a>
#             </span>
#            </li>
#            <li class="item2 odd">
#             <span class="field-label">
#              <a href="/myligue/cgu">
#               CGU
#              </a>
#             </span>
#            </li>
#            <li class="item3 even">
#             <span class="field-label">
#              <a href="/politique-de-confidentialite">
#               Confidentialité
#              </a>
#             </span>
#            </li>
#            <li class="item4 odd">
#             <span class="field-label">
#              <a href="/contact">
#               Contact
#              </a>
#             </span>
#            </li>
#            <li class="item5 even">
#             <span class="field-label">
#              <a href="https://www.lfp.fr/chartes-medias" rel="noopener noreferrer" target="_blank">
#               Médias
#              </a>
#             </span>
#            </li>
#            <li class="item6 odd">
#             <span class="field-label">
#              <a href="https://www.lfp.fr" rel="noopener noreferrer" target="_blank">
#               lfp.fr
#              </a>
#             </span>
#            </li>
#            <li class="item7 even last">
#             <span class="field-label">
#              <a href="https://www.ligue1.com" rel="noopener noreferrer" target="_blank">
#               ligue1.com
#              </a>
#             </span>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <!-- /#footer -->
#   <!-- Tarteaucitron services -->
#   <script src="//opt-out.ferank.eu/tarteaucitron.js?domain=www.ligue1.fr&amp;uuid=2ebfadfeac3274b320a17e6741d1dd2f936ef248" type="text/javascript">
#   </script>
#   <!-- End Tarteaucitron services -->
#   <script src="/-/media/Base-Themes/Core-Libraries/scripts/optimized-min.js?t=20200129T015531Z">
#   </script>
#   <script src="/-/media/Base-Themes/XA-API/Scripts/optimized-min.js?t=20200129T015534Z">
#   </script>
#   <script src="/-/media/Base-Themes/Main-Theme/scripts/optimized-min.js?t=20200129T015536Z">
#   </script>
#   <script src="/-/media/Base-Themes/Variants/Scripts/optimized-min.js?t=20200129T015541Z">
#   </script>
#   <script src="/-/media/Base-Themes/Components-Theme/Scripts/optimized-min.js?t=20200129T015542Z">
#   </script>
#   <script src="/-/media/Base-Themes/Google-Maps-JS-Connector/Scripts/optimized-min.js?t=20200129T015544Z">
#   </script>
#   <script src="/-/media/Base-Themes/Maps/Scripts/optimized-min.js?t=20200129T015545Z">
#   </script>
#   <script src="/-/media/Base-Themes/SearchTheme/Scripts/optimized-min.js?t=20200129T015547Z">
#   </script>
#   <script src="/-/media/Base-Themes/Resolve-Conflicts/Scripts/optimized-min.js?t=20200129T015548Z">
#   </script>
#   <script src="/-/media/Base-Themes/LFP/Scripts/optimized-min.js?t=20200129T015550Z">
#   </script>
#   <script src="/-/media/Base-Themes/LFPCompetition/Scripts/optimized-min.js?t=20200129T015552Z">
#   </script>
#   <script src="/-/media/Base-Themes/LFPRanking/Scripts/optimized-min.js?t=20200129T015553Z">
#   </script>
#   <script src="/-/media/Themes/LFP/Ligue1/Ligue1/Scripts/optimized-min.js?t=20200130T092629Z">
#   </script>
#   <!-- /#wrapper -->
#  </body>
# </html>

# %%
table = soup.find(class_='player-stats-table')
print(table.prettify())
# Out:
# <div class="player-stats-table">
#  <div class="player-stats-table-heading">
#   <div class="player-stats-row-rank-label">
#    POSITION
#   </div>
#   <div class="player-stats-row-player-label">
#    Joueur
#   </div>
#   <div class="player-stats-row-club-label">
#    Club
#   </div>
#   <div class="player-stats-row-country-label">
#    Nationalité
#   </div>
#   <div class="player-stats-row-goals-label">
#    Buts
#   </div>
#  </div>
#  <div class="player-my-stats-table-body">
#   <ul class="rank-widget rank-result-list js-slick">
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        1
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/36516.jpg"/>
#        </span>
#        Wissam BEN YEDDER
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9.png"/>
#        </span>
#        AS MONACO
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        16
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         1
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/36516.jpg"/>
#         </span>
#         <p>
#          Wissam BEN YEDDER
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         16
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        2
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/56621.jpg"/>
#        </span>
#        Kylian MBAPPE
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/13.png"/>
#        </span>
#        PARIS SAINT-GERMAIN
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        15
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         2
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/56621.jpg"/>
#         </span>
#         <p>
#          Kylian MBAPPE
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/13.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         15
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        3
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/36408.jpg"/>
#        </span>
#        Moussa DEMBELE
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/159.png"/>
#        </span>
#        OLYMPIQUE LYONNAIS
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        13
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         3
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/36408.jpg"/>
#         </span>
#         <p>
#          Moussa DEMBELE
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/159.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         13
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        4
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/82425.jpg"/>
#        </span>
#        NEYMAR JR
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/13.png"/>
#        </span>
#        PARIS SAINT-GERMAIN
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="BRE" src="/-/media/Project/LFP/shared/Images/Country/BRE.jpg"/>
#        </span>
#        BRE
#       </div>
#       <div class="player-stats-row-goals">
#        13
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         4
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/82425.jpg"/>
#         </span>
#         <p>
#          NEYMAR JR
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/13.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         13
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        5
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/56360.jpg"/>
#        </span>
#        Habib DIALLO
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/8.png"/>
#        </span>
#        FC METZ
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="SEN" src="/-/media/Project/LFP/shared/Images/Country/SEN.jpg"/>
#        </span>
#        SEN
#       </div>
#       <div class="player-stats-row-goals">
#        12
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         5
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/56360.jpg"/>
#         </span>
#         <p>
#          Habib DIALLO
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/8.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         12
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        6
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89177.jpg"/>
#        </span>
#        Victor OSIMHEN
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/158.png"/>
#        </span>
#        LOSC LILLE
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="NIG" src="/-/media/Project/LFP/shared/Images/Country/NIG.jpg"/>
#        </span>
#        NIG
#       </div>
#       <div class="player-stats-row-goals">
#        12
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         6
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89177.jpg"/>
#         </span>
#         <p>
#          Victor OSIMHEN
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/158.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         12
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        7
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89885.jpg"/>
#        </span>
#        Mauro ICARDI
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/13.png"/>
#        </span>
#        PARIS SAINT-GERMAIN
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="ARG" src="/-/media/Project/LFP/shared/Images/Country/ARG.jpg"/>
#        </span>
#        ARG
#       </div>
#       <div class="player-stats-row-goals">
#        10
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         7
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89885.jpg"/>
#         </span>
#         <p>
#          Mauro ICARDI
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/13.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         10
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        8
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/29323.jpg"/>
#        </span>
#        Andy DELORT
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/10.png"/>
#        </span>
#        MONTPELLIER HÉRAULT SC
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        9
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         8
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/29323.jpg"/>
#         </span>
#         <p>
#          Andy DELORT
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/10.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         9
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        9
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/80592.jpg"/>
#        </span>
#        Memphis DEPAY
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/159.png"/>
#        </span>
#        OLYMPIQUE LYONNAIS
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="HOL" src="/-/media/Project/LFP/shared/Images/Country/HOL.jpg"/>
#        </span>
#        HOL
#       </div>
#       <div class="player-stats-row-goals">
#        9
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         9
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/80592.jpg"/>
#         </span>
#         <p>
#          Memphis DEPAY
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/159.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         9
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        10
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/47824.jpg"/>
#        </span>
#        Adrien THOMASSON
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/15.png"/>
#        </span>
#        RC STRASBOURG ALSACE
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        8
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         10
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/47824.jpg"/>
#         </span>
#         <p>
#          Adrien THOMASSON
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/15.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         8
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        11
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89821.jpg"/>
#        </span>
#        Kasper DOLBERG
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/30.png"/>
#        </span>
#        OGC NICE
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="DAN" src="/-/media/Project/LFP/shared/Images/Country/DAN.jpg"/>
#        </span>
#        DAN
#       </div>
#       <div class="player-stats-row-goals">
#        8
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         11
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89821.jpg"/>
#         </span>
#         <p>
#          Kasper DOLBERG
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/30.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         8
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        12
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/19087.jpg"/>
#        </span>
#        M'Baye NIANG
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/14.png"/>
#        </span>
#        STADE RENNAIS FC
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        8
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         12
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/19087.jpg"/>
#         </span>
#         <p>
#          M'Baye NIANG
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/14.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         8
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        13
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/68806.jpg"/>
#        </span>
#        Angel DI MARIA
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/13.png"/>
#        </span>
#        PARIS SAINT-GERMAIN
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="ARG" src="/-/media/Project/LFP/shared/Images/Country/ARG.jpg"/>
#        </span>
#        ARG
#       </div>
#       <div class="player-stats-row-goals">
#        8
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         13
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/68806.jpg"/>
#         </span>
#         <p>
#          Angel DI MARIA
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/13.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         8
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        14
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/57211.jpg"/>
#        </span>
#        Islam SLIMANI
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9.png"/>
#        </span>
#        AS MONACO
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="ALG" src="/-/media/Project/LFP/shared/Images/Country/ALG.jpg"/>
#        </span>
#        ALG
#       </div>
#       <div class="player-stats-row-goals">
#        8
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         14
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/57211.jpg"/>
#         </span>
#         <p>
#          Islam SLIMANI
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         8
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        15
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/56118.jpg"/>
#        </span>
#        Ludovic AJORQUE
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/15.png"/>
#        </span>
#        RC STRASBOURG ALSACE
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        8
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         15
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/56118.jpg"/>
#         </span>
#         <p>
#          Ludovic AJORQUE
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/15.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         8
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        16
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/26512.jpg"/>
#        </span>
#        Dimitri PAYET
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/1.png"/>
#        </span>
#        OLYMPIQUE DE MARSEILLE
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        8
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         16
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/26512.jpg"/>
#         </span>
#         <p>
#          Dimitri PAYET
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/1.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         8
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        17
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89457.jpg"/>
#        </span>
#        Dario BENEDETTO
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/1.png"/>
#        </span>
#        OLYMPIQUE DE MARSEILLE
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="ARG" src="/-/media/Project/LFP/shared/Images/Country/ARG.jpg"/>
#        </span>
#        ARG
#       </div>
#       <div class="player-stats-row-goals">
#        7
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         17
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89457.jpg"/>
#         </span>
#         <p>
#          Dario BENEDETTO
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/1.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         7
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        18
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/52974.jpg"/>
#        </span>
#        Denis BOUANGA
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/31.png"/>
#        </span>
#        AS SAINT-ÉTIENNE
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="GAB" src="/-/media/Project/LFP/shared/Images/Country/GAB.jpg"/>
#        </span>
#        GAB
#       </div>
#       <div class="player-stats-row-goals">
#        7
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         18
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/52974.jpg"/>
#         </span>
#         <p>
#          Denis BOUANGA
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/31.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         7
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        19
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/36102.jpg"/>
#        </span>
#        Wylan CYPRIEN
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/30.png"/>
#        </span>
#        OGC NICE
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        7
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         19
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/36102.jpg"/>
#         </span>
#         <p>
#          Wylan CYPRIEN
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/30.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         7
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        20
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/48017.jpg"/>
#        </span>
#        Florent MOLLET
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/10.png"/>
#        </span>
#        MONTPELLIER HÉRAULT SC
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        6
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         20
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/48017.jpg"/>
#         </span>
#         <p>
#          Florent MOLLET
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/10.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         6
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        21
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/84847.jpg"/>
#        </span>
#        Boulaye DIA
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/41.png"/>
#        </span>
#        STADE DE REIMS
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        6
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         21
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/84847.jpg"/>
#         </span>
#         <p>
#          Boulaye DIA
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/41.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         6
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        22
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/15709.jpg"/>
#        </span>
#        Romain HAMOUMA
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/31.png"/>
#        </span>
#        AS SAINT-ÉTIENNE
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        6
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         22
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/15709.jpg"/>
#         </span>
#         <p>
#          Romain HAMOUMA
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/31.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         6
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        23
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/35732.jpg"/>
#        </span>
#        Rachid ALIOUI
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/37.png"/>
#        </span>
#        ANGERS SCO
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        6
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         23
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/35732.jpg"/>
#         </span>
#         <p>
#          Rachid ALIOUI
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/37.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         6
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        24
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/26707.jpg"/>
#        </span>
#        Adrien HUNOU
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/14.png"/>
#        </span>
#        STADE RENNAIS FC
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        6
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         24
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/26707.jpg"/>
#         </span>
#         <p>
#          Adrien HUNOU
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/14.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         6
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        25
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/28916.jpg"/>
#        </span>
#        Jimmy BRIAND
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/4.png"/>
#        </span>
#        FC GIRONDINS DE BORDEAUX
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        6
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         25
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/28916.jpg"/>
#         </span>
#         <p>
#          Jimmy BRIAND
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/4.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         6
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        26
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/45195.jpg"/>
#        </span>
#        Serhou GUIRASSY
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/18.png"/>
#        </span>
#        AMIENS SC
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        6
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         26
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/45195.jpg"/>
#         </span>
#         <p>
#          Serhou GUIRASSY
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/18.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         6
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        27
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89637.jpg"/>
#        </span>
#        Moses SIMON
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/12.png"/>
#        </span>
#        FC NANTES
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="NIG" src="/-/media/Project/LFP/shared/Images/Country/NIG.jpg"/>
#        </span>
#        NIG
#       </div>
#       <div class="player-stats-row-goals">
#        5
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         27
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89637.jpg"/>
#         </span>
#         <p>
#          Moses SIMON
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/12.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         5
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        28
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/35324.jpg"/>
#        </span>
#        Gaëtan LABORDE
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/10.png"/>
#        </span>
#        MONTPELLIER HÉRAULT SC
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        5
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         28
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/35324.jpg"/>
#         </span>
#         <p>
#          Gaëtan LABORDE
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/10.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         5
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        29
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/34398.jpg"/>
#        </span>
#        Irvin CARDONA
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/44.png"/>
#        </span>
#        STADE BRESTOIS 29
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        5
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         29
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/34398.jpg"/>
#         </span>
#         <p>
#          Irvin CARDONA
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/44.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         5
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        30
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/53867.jpg"/>
#        </span>
#        Romain PHILIPPOTEAUX
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/27.png"/>
#        </span>
#        NÎMES OLYMPIQUE
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        5
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         30
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/53867.jpg"/>
#         </span>
#         <p>
#          Romain PHILIPPOTEAUX
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/27.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         5
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        31
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/88827.jpg"/>
#        </span>
#        Mama BALDE
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/74.png"/>
#        </span>
#        DIJON FCO
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="POR" src="/-/media/Project/LFP/shared/Images/Country/POR.jpg"/>
#        </span>
#        POR
#       </div>
#       <div class="player-stats-row-goals">
#        5
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         31
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/88827.jpg"/>
#         </span>
#         <p>
#          Mama BALDE
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/74.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         5
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        32
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/86714.jpg"/>
#        </span>
#        Josh MAJA
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/4.png"/>
#        </span>
#        FC GIRONDINS DE BORDEAUX
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="NIG" src="/-/media/Project/LFP/shared/Images/Country/NIG.jpg"/>
#        </span>
#        NIG
#       </div>
#       <div class="player-stats-row-goals">
#        5
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         32
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/86714.jpg"/>
#         </span>
#         <p>
#          Josh MAJA
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/4.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         5
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        33
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/85870.jpg"/>
#        </span>
#        Nemanja RADONJIC
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/1.png"/>
#        </span>
#        OLYMPIQUE DE MARSEILLE
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="SER" src="/-/media/Project/LFP/shared/Images/Country/SER.jpg"/>
#        </span>
#        SER
#       </div>
#       <div class="player-stats-row-goals">
#        5
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         33
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/85870.jpg"/>
#         </span>
#         <p>
#          Nemanja RADONJIC
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/1.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         5
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        34
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/52480.jpg"/>
#        </span>
#        Ludovic BLAS
#       </div>
#       <div class="player-stats-row-club">
#        <span>
# ...
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/74.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         5
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        40
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/28858.jpg"/>
#        </span>
#        Pierre LEES-MELOU
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/30.png"/>
#        </span>
#        OGC NICE
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         40
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/28858.jpg"/>
#         </span>
#         <p>
#          Pierre LEES-MELOU
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/30.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         4
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        41
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/82882.jpg"/>
#        </span>
#        Keita BALDE
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9.png"/>
#        </span>
#        AS MONACO
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="SEN" src="/-/media/Project/LFP/shared/Images/Country/SEN.jpg"/>
#        </span>
#        SEN
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         41
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/82882.jpg"/>
#         </span>
#         <p>
#          Keita BALDE
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         4
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        42
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/17759.jpg"/>
#        </span>
#        Maxwel CORNET
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/159.png"/>
#        </span>
#        OLYMPIQUE LYONNAIS
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="IVO" src="/-/media/Project/LFP/shared/Images/Country/IVO.jpg"/>
#        </span>
#        IVO
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         42
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/17759.jpg"/>
#         </span>
#         <p>
#          Maxwel CORNET
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/159.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         4
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        43
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89109.jpg"/>
#        </span>
#        Ui-Jo HWANG
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/4.png"/>
#        </span>
#        FC GIRONDINS DE BORDEAUX
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="CSU" src="/-/media/Project/LFP/shared/Images/Country/CSU.jpg"/>
#        </span>
#        CSU
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         43
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89109.jpg"/>
#         </span>
#         <p>
#          Ui-Jo HWANG
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/4.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         4
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        44
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/50013.jpg"/>
#        </span>
#        Rémi OUDIN
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/4.png"/>
#        </span>
#        FC GIRONDINS DE BORDEAUX
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         44
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/50013.jpg"/>
#         </span>
#         <p>
#          Rémi OUDIN
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/4.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         4
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        45
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/44173.jpg"/>
#        </span>
#        Opa NGUETTE
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/8.png"/>
#        </span>
#        FC METZ
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         45
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/44173.jpg"/>
#         </span>
#         <p>
#          Opa NGUETTE
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/8.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         4
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        46
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/88769.jpg"/>
#        </span>
#        Efthymios KOULOURIS
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/16.png"/>
#        </span>
#        TOULOUSE FC
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="GRE" src="/-/media/Project/LFP/shared/Images/Country/GRE.jpg"/>
#        </span>
#        GRE
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         46
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/88769.jpg"/>
#         </span>
#         <p>
#          Efthymios KOULOURIS
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/16.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         4
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        47
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/86713.jpg"/>
#        </span>
#        Gelson MARTINS
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9.png"/>
#        </span>
#        AS MONACO
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="POR" src="/-/media/Project/LFP/shared/Images/Country/POR.jpg"/>
#        </span>
#        POR
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         47
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/86713.jpg"/>
#         </span>
#         <p>
#          Gelson MARTINS
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         4
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        48
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/16021.jpg"/>
#        </span>
#        Loïc REMY
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/158.png"/>
#        </span>
#        LOSC LILLE
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         48
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/16021.jpg"/>
#         </span>
#         <p>
#          Loïc REMY
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/158.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         4
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        49
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/39730.jpg"/>
#        </span>
#        Kalifa COULIBALY
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/12.png"/>
#        </span>
#        FC NANTES
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="MAI" src="/-/media/Project/LFP/shared/Images/Country/MAI.jpg"/>
#        </span>
#        MAI
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         49
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/39730.jpg"/>
#         </span>
#         <p>
#          Kalifa COULIBALY
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/12.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         4
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#    <li class="rank-result">
#     <div class="stats-row">
#      <div class="desktop-item">
#       <div class="player-stats-row-rank">
#        50
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/26662.jpg"/>
#        </span>
#        Téji SAVANIER
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/10.png"/>
#        </span>
#        MONTPELLIER HÉRAULT SC
#       </div>
#       <div class="player-stats-row-country">
#        <span>
#         <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#        </span>
#        FRA
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#      <div class="mobile-item">
#       <div class="stats-row-head">
#        <div class="player-stats-row-rank">
#         50
#        </div>
#        <div class="player-stats-row-player">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/26662.jpg"/>
#         </span>
#         <p>
#          Téji SAVANIER
#         </p>
#        </div>
#        <div class="player-stats-row-club">
#         <span>
#          <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/10.png"/>
#         </span>
#        </div>
#        <div class="player-stats-row-goals">
#         4
#        </div>
#       </div>
#      </div>
#     </div>
#    </li>
#   </ul>
#  </div>
#  <div class="player-stats-table-controls">
#  </div>
# </div>

# %%
head = table.find(class_='player-stats-table-heading')
print(head.prettify())
# Out:
# <div class="player-stats-table-heading">
#  <div class="player-stats-row-rank-label">
#   POSITION
#  </div>
#  <div class="player-stats-row-player-label">
#   Joueur
#  </div>
#  <div class="player-stats-row-club-label">
#   Club
#  </div>
#  <div class="player-stats-row-country-label">
#   Nationalité
#  </div>
#  <div class="player-stats-row-goals-label">
#   Buts
#  </div>
# </div>

# %%
table_head = head.find_all('div')
for s in table_head:
    print(s.contents[0], end='\t')
# Out:
# POSITION	Joueur	Club	Nationalité	Buts

# %%
print(table_head)
# Out:
# [<div class="player-stats-row-rank-label">POSITION</div>, <div class="player-stats-row-player-label">Joueur</div>, <div class="player-stats-row-club-label">Club</div>, <div class="player-stats-row-country-label">Nationalité</div>, <div class="player-stats-row-goals-label">Buts</div>]

# %%
body = table.find(class_='player-my-stats-table-body')
print(body.prettify())
# Out:
# <div class="player-my-stats-table-body">
#  <ul class="rank-widget rank-result-list js-slick">
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       1
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/36516.jpg"/>
#       </span>
#       Wissam BEN YEDDER
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9.png"/>
#       </span>
#       AS MONACO
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       16
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        1
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/36516.jpg"/>
#        </span>
#        <p>
#         Wissam BEN YEDDER
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        16
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       2
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/56621.jpg"/>
#       </span>
#       Kylian MBAPPE
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/13.png"/>
#       </span>
#       PARIS SAINT-GERMAIN
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       15
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        2
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/56621.jpg"/>
#        </span>
#        <p>
#         Kylian MBAPPE
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/13.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        15
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       3
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/36408.jpg"/>
#       </span>
#       Moussa DEMBELE
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/159.png"/>
#       </span>
#       OLYMPIQUE LYONNAIS
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       13
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        3
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/36408.jpg"/>
#        </span>
#        <p>
#         Moussa DEMBELE
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/159.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        13
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       4
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/82425.jpg"/>
#       </span>
#       NEYMAR JR
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/13.png"/>
#       </span>
#       PARIS SAINT-GERMAIN
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="BRE" src="/-/media/Project/LFP/shared/Images/Country/BRE.jpg"/>
#       </span>
#       BRE
#      </div>
#      <div class="player-stats-row-goals">
#       13
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        4
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/82425.jpg"/>
#        </span>
#        <p>
#         NEYMAR JR
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/13.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        13
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       5
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/56360.jpg"/>
#       </span>
#       Habib DIALLO
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/8.png"/>
#       </span>
#       FC METZ
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="SEN" src="/-/media/Project/LFP/shared/Images/Country/SEN.jpg"/>
#       </span>
#       SEN
#      </div>
#      <div class="player-stats-row-goals">
#       12
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        5
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/56360.jpg"/>
#        </span>
#        <p>
#         Habib DIALLO
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/8.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        12
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       6
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89177.jpg"/>
#       </span>
#       Victor OSIMHEN
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/158.png"/>
#       </span>
#       LOSC LILLE
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="NIG" src="/-/media/Project/LFP/shared/Images/Country/NIG.jpg"/>
#       </span>
#       NIG
#      </div>
#      <div class="player-stats-row-goals">
#       12
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        6
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89177.jpg"/>
#        </span>
#        <p>
#         Victor OSIMHEN
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/158.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        12
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       7
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89885.jpg"/>
#       </span>
#       Mauro ICARDI
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/13.png"/>
#       </span>
#       PARIS SAINT-GERMAIN
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="ARG" src="/-/media/Project/LFP/shared/Images/Country/ARG.jpg"/>
#       </span>
#       ARG
#      </div>
#      <div class="player-stats-row-goals">
#       10
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        7
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89885.jpg"/>
#        </span>
#        <p>
#         Mauro ICARDI
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/13.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        10
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       8
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/29323.jpg"/>
#       </span>
#       Andy DELORT
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/10.png"/>
#       </span>
#       MONTPELLIER HÉRAULT SC
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       9
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        8
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/29323.jpg"/>
#        </span>
#        <p>
#         Andy DELORT
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/10.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        9
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       9
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/80592.jpg"/>
#       </span>
#       Memphis DEPAY
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/159.png"/>
#       </span>
#       OLYMPIQUE LYONNAIS
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="HOL" src="/-/media/Project/LFP/shared/Images/Country/HOL.jpg"/>
#       </span>
#       HOL
#      </div>
#      <div class="player-stats-row-goals">
#       9
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        9
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/80592.jpg"/>
#        </span>
#        <p>
#         Memphis DEPAY
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/159.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        9
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       10
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/47824.jpg"/>
#       </span>
#       Adrien THOMASSON
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/15.png"/>
#       </span>
#       RC STRASBOURG ALSACE
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       8
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        10
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/47824.jpg"/>
#        </span>
#        <p>
#         Adrien THOMASSON
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/15.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        8
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       11
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89821.jpg"/>
#       </span>
#       Kasper DOLBERG
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/30.png"/>
#       </span>
#       OGC NICE
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="DAN" src="/-/media/Project/LFP/shared/Images/Country/DAN.jpg"/>
#       </span>
#       DAN
#      </div>
#      <div class="player-stats-row-goals">
#       8
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        11
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89821.jpg"/>
#        </span>
#        <p>
#         Kasper DOLBERG
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/30.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        8
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       12
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/19087.jpg"/>
#       </span>
#       M'Baye NIANG
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/14.png"/>
#       </span>
#       STADE RENNAIS FC
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       8
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        12
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/19087.jpg"/>
#        </span>
#        <p>
#         M'Baye NIANG
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/14.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        8
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       13
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/68806.jpg"/>
#       </span>
#       Angel DI MARIA
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/13.png"/>
#       </span>
#       PARIS SAINT-GERMAIN
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="ARG" src="/-/media/Project/LFP/shared/Images/Country/ARG.jpg"/>
#       </span>
#       ARG
#      </div>
#      <div class="player-stats-row-goals">
#       8
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        13
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/68806.jpg"/>
#        </span>
#        <p>
#         Angel DI MARIA
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/13.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        8
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       14
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/57211.jpg"/>
#       </span>
#       Islam SLIMANI
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9.png"/>
#       </span>
#       AS MONACO
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="ALG" src="/-/media/Project/LFP/shared/Images/Country/ALG.jpg"/>
#       </span>
#       ALG
#      </div>
#      <div class="player-stats-row-goals">
#       8
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        14
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/57211.jpg"/>
#        </span>
#        <p>
#         Islam SLIMANI
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        8
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       15
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/56118.jpg"/>
#       </span>
#       Ludovic AJORQUE
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/15.png"/>
#       </span>
#       RC STRASBOURG ALSACE
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       8
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        15
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/56118.jpg"/>
#        </span>
#        <p>
#         Ludovic AJORQUE
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/15.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        8
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       16
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/26512.jpg"/>
#       </span>
#       Dimitri PAYET
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/1.png"/>
#       </span>
#       OLYMPIQUE DE MARSEILLE
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       8
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        16
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/26512.jpg"/>
#        </span>
#        <p>
#         Dimitri PAYET
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/1.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        8
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       17
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89457.jpg"/>
#       </span>
#       Dario BENEDETTO
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/1.png"/>
#       </span>
#       OLYMPIQUE DE MARSEILLE
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="ARG" src="/-/media/Project/LFP/shared/Images/Country/ARG.jpg"/>
#       </span>
#       ARG
#      </div>
#      <div class="player-stats-row-goals">
#       7
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        17
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89457.jpg"/>
#        </span>
#        <p>
#         Dario BENEDETTO
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/1.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        7
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       18
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/52974.jpg"/>
#       </span>
#       Denis BOUANGA
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/31.png"/>
#       </span>
#       AS SAINT-ÉTIENNE
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="GAB" src="/-/media/Project/LFP/shared/Images/Country/GAB.jpg"/>
#       </span>
#       GAB
#      </div>
#      <div class="player-stats-row-goals">
#       7
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        18
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/52974.jpg"/>
#        </span>
#        <p>
#         Denis BOUANGA
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/31.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        7
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       19
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/36102.jpg"/>
#       </span>
#       Wylan CYPRIEN
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/30.png"/>
#       </span>
#       OGC NICE
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       7
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        19
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/36102.jpg"/>
#        </span>
#        <p>
#         Wylan CYPRIEN
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/30.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        7
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       20
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/48017.jpg"/>
#       </span>
#       Florent MOLLET
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/10.png"/>
#       </span>
#       MONTPELLIER HÉRAULT SC
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       6
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        20
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/48017.jpg"/>
#        </span>
#        <p>
#         Florent MOLLET
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/10.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        6
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       21
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/84847.jpg"/>
#       </span>
#       Boulaye DIA
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/41.png"/>
#       </span>
#       STADE DE REIMS
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       6
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        21
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/84847.jpg"/>
#        </span>
#        <p>
#         Boulaye DIA
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/41.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        6
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       22
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/15709.jpg"/>
#       </span>
#       Romain HAMOUMA
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/31.png"/>
#       </span>
#       AS SAINT-ÉTIENNE
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       6
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        22
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/15709.jpg"/>
#        </span>
#        <p>
#         Romain HAMOUMA
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/31.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        6
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       23
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/35732.jpg"/>
#       </span>
#       Rachid ALIOUI
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/37.png"/>
#       </span>
#       ANGERS SCO
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       6
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        23
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/35732.jpg"/>
#        </span>
#        <p>
#         Rachid ALIOUI
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/37.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        6
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       24
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/26707.jpg"/>
#       </span>
#       Adrien HUNOU
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/14.png"/>
#       </span>
#       STADE RENNAIS FC
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       6
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        24
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/26707.jpg"/>
#        </span>
#        <p>
#         Adrien HUNOU
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/14.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        6
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       25
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/28916.jpg"/>
#       </span>
#       Jimmy BRIAND
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/4.png"/>
#       </span>
#       FC GIRONDINS DE BORDEAUX
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       6
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        25
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/28916.jpg"/>
#        </span>
#        <p>
#         Jimmy BRIAND
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/4.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        6
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       26
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/45195.jpg"/>
#       </span>
#       Serhou GUIRASSY
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/18.png"/>
#       </span>
#       AMIENS SC
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       6
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        26
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/45195.jpg"/>
#        </span>
#        <p>
#         Serhou GUIRASSY
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/18.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        6
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       27
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89637.jpg"/>
#       </span>
#       Moses SIMON
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/12.png"/>
#       </span>
#       FC NANTES
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="NIG" src="/-/media/Project/LFP/shared/Images/Country/NIG.jpg"/>
#       </span>
#       NIG
#      </div>
#      <div class="player-stats-row-goals">
#       5
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        27
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89637.jpg"/>
#        </span>
#        <p>
#         Moses SIMON
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/12.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        5
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       28
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/35324.jpg"/>
#       </span>
#       Gaëtan LABORDE
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/10.png"/>
#       </span>
#       MONTPELLIER HÉRAULT SC
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       5
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        28
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/35324.jpg"/>
#        </span>
#        <p>
#         Gaëtan LABORDE
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/10.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        5
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       29
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/34398.jpg"/>
#       </span>
#       Irvin CARDONA
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/44.png"/>
#       </span>
#       STADE BRESTOIS 29
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       5
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        29
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/34398.jpg"/>
#        </span>
#        <p>
#         Irvin CARDONA
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/44.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        5
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       30
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/53867.jpg"/>
#       </span>
#       Romain PHILIPPOTEAUX
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/27.png"/>
#       </span>
#       NÎMES OLYMPIQUE
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       5
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        30
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/53867.jpg"/>
#        </span>
#        <p>
#         Romain PHILIPPOTEAUX
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/27.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        5
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       31
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/88827.jpg"/>
#       </span>
#       Mama BALDE
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/74.png"/>
#       </span>
#       DIJON FCO
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="POR" src="/-/media/Project/LFP/shared/Images/Country/POR.jpg"/>
#       </span>
#       POR
#      </div>
#      <div class="player-stats-row-goals">
#       5
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        31
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/88827.jpg"/>
#        </span>
#        <p>
#         Mama BALDE
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/74.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        5
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       32
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/86714.jpg"/>
#       </span>
#       Josh MAJA
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/4.png"/>
#       </span>
#       FC GIRONDINS DE BORDEAUX
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="NIG" src="/-/media/Project/LFP/shared/Images/Country/NIG.jpg"/>
#       </span>
#       NIG
#      </div>
#      <div class="player-stats-row-goals">
#       5
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        32
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/86714.jpg"/>
#        </span>
#        <p>
#         Josh MAJA
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/4.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        5
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       33
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/85870.jpg"/>
#       </span>
#       Nemanja RADONJIC
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/1.png"/>
#       </span>
#       OLYMPIQUE DE MARSEILLE
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="SER" src="/-/media/Project/LFP/shared/Images/Country/SER.jpg"/>
#       </span>
#       SER
#      </div>
#      <div class="player-stats-row-goals">
#       5
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        33
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/85870.jpg"/>
#        </span>
#        <p>
#         Nemanja RADONJIC
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/1.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        5
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       34
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/52480.jpg"/>
#       </span>
#       Ludovic BLAS
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/12.png"/>
#       </span>
#       FC NANTES
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       5
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        34
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/52480.jpg"/>
#        </span>
#        <p>
#         Ludovic BLAS
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/12.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        5
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       35
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/83686.jpg"/>
#       </span>
#       Steven MENDOZA
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/18.png"/>
#       </span>
#       AMIENS SC
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="COL" src="/-/media/Project/LFP/shared/Images/Country/COL.jpg"/>
#       </span>
#       COL
#      </div>
#      <div class="player-stats-row-goals">
#       5
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        35
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/83686.jpg"/>
#        </span>
#        <p>
#         Steven MENDOZA
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
# ...
#       </span>
#       DIJON FCO
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="CAP" src="/-/media/Project/LFP/shared/Images/Country/CAP.jpg"/>
#       </span>
#       CAP
#      </div>
#      <div class="player-stats-row-goals">
#       5
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        39
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/50652.jpg"/>
#        </span>
#        <p>
#         Julio TAVARES
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/74.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        5
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       40
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/28858.jpg"/>
#       </span>
#       Pierre LEES-MELOU
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/30.png"/>
#       </span>
#       OGC NICE
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       4
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        40
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/28858.jpg"/>
#        </span>
#        <p>
#         Pierre LEES-MELOU
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/30.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       41
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/82882.jpg"/>
#       </span>
#       Keita BALDE
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9.png"/>
#       </span>
#       AS MONACO
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="SEN" src="/-/media/Project/LFP/shared/Images/Country/SEN.jpg"/>
#       </span>
#       SEN
#      </div>
#      <div class="player-stats-row-goals">
#       4
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        41
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/82882.jpg"/>
#        </span>
#        <p>
#         Keita BALDE
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       42
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/17759.jpg"/>
#       </span>
#       Maxwel CORNET
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/159.png"/>
#       </span>
#       OLYMPIQUE LYONNAIS
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="IVO" src="/-/media/Project/LFP/shared/Images/Country/IVO.jpg"/>
#       </span>
#       IVO
#      </div>
#      <div class="player-stats-row-goals">
#       4
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        42
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/17759.jpg"/>
#        </span>
#        <p>
#         Maxwel CORNET
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/159.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       43
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89109.jpg"/>
#       </span>
#       Ui-Jo HWANG
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/4.png"/>
#       </span>
#       FC GIRONDINS DE BORDEAUX
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="CSU" src="/-/media/Project/LFP/shared/Images/Country/CSU.jpg"/>
#       </span>
#       CSU
#      </div>
#      <div class="player-stats-row-goals">
#       4
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        43
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/89109.jpg"/>
#        </span>
#        <p>
#         Ui-Jo HWANG
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/4.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       44
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/50013.jpg"/>
#       </span>
#       Rémi OUDIN
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/4.png"/>
#       </span>
#       FC GIRONDINS DE BORDEAUX
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       4
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        44
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/50013.jpg"/>
#        </span>
#        <p>
#         Rémi OUDIN
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/4.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       45
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/44173.jpg"/>
#       </span>
#       Opa NGUETTE
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/8.png"/>
#       </span>
#       FC METZ
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       4
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        45
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/44173.jpg"/>
#        </span>
#        <p>
#         Opa NGUETTE
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/8.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       46
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/88769.jpg"/>
#       </span>
#       Efthymios KOULOURIS
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/16.png"/>
#       </span>
#       TOULOUSE FC
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="GRE" src="/-/media/Project/LFP/shared/Images/Country/GRE.jpg"/>
#       </span>
#       GRE
#      </div>
#      <div class="player-stats-row-goals">
#       4
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        46
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/88769.jpg"/>
#        </span>
#        <p>
#         Efthymios KOULOURIS
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/16.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       47
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/86713.jpg"/>
#       </span>
#       Gelson MARTINS
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9.png"/>
#       </span>
#       AS MONACO
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="POR" src="/-/media/Project/LFP/shared/Images/Country/POR.jpg"/>
#       </span>
#       POR
#      </div>
#      <div class="player-stats-row-goals">
#       4
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        47
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/86713.jpg"/>
#        </span>
#        <p>
#         Gelson MARTINS
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       48
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/16021.jpg"/>
#       </span>
#       Loïc REMY
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/158.png"/>
#       </span>
#       LOSC LILLE
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       4
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        48
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/16021.jpg"/>
#        </span>
#        <p>
#         Loïc REMY
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/158.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       49
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/39730.jpg"/>
#       </span>
#       Kalifa COULIBALY
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/12.png"/>
#       </span>
#       FC NANTES
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="MAI" src="/-/media/Project/LFP/shared/Images/Country/MAI.jpg"/>
#       </span>
#       MAI
#      </div>
#      <div class="player-stats-row-goals">
#       4
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        49
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/39730.jpg"/>
#        </span>
#        <p>
#         Kalifa COULIBALY
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/12.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#   <li class="rank-result">
#    <div class="stats-row">
#     <div class="desktop-item">
#      <div class="player-stats-row-rank">
#       50
#      </div>
#      <div class="player-stats-row-player">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/26662.jpg"/>
#       </span>
#       Téji SAVANIER
#      </div>
#      <div class="player-stats-row-club">
#       <span>
#        <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/10.png"/>
#       </span>
#       MONTPELLIER HÉRAULT SC
#      </div>
#      <div class="player-stats-row-country">
#       <span>
#        <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#       </span>
#       FRA
#      </div>
#      <div class="player-stats-row-goals">
#       4
#      </div>
#     </div>
#     <div class="mobile-item">
#      <div class="stats-row-head">
#       <div class="player-stats-row-rank">
#        50
#       </div>
#       <div class="player-stats-row-player">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/26662.jpg"/>
#        </span>
#        <p>
#         Téji SAVANIER
#        </p>
#       </div>
#       <div class="player-stats-row-club">
#        <span>
#         <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/10.png"/>
#        </span>
#       </div>
#       <div class="player-stats-row-goals">
#        4
#       </div>
#      </div>
#     </div>
#    </div>
#   </li>
#  </ul>
# </div>

# %%
li_tags = body.find_all(class_='desktop-item')
#print(li_tags)
print(len(li_tags), li_tags[0].prettify())
# Out:
# 50 <div class="desktop-item">
#  <div class="player-stats-row-rank">
#   1
#  </div>
#  <div class="player-stats-row-player">
#   <span>
#    <img src="/-/media/Project/LFP/shared/Images/Players/2019-2020/36516.jpg"/>
#   </span>
#   Wissam BEN YEDDER
#  </div>
#  <div class="player-stats-row-club">
#   <span>
#    <img src="/-/media/Project/LFP/shared/Images/Clubs/2019-2020/9.png"/>
#   </span>
#   AS MONACO
#  </div>
#  <div class="player-stats-row-country">
#   <span>
#    <img alt="FRA" src="/-/media/Project/LFP/shared/Images/Country/FRA.jpg"/>
#   </span>
#   FRA
#  </div>
#  <div class="player-stats-row-goals">
#   16
#  </div>
# </div>

# %%
col = li_tags[0].find_all('div')
print(col[1].contents[2])
print(col[2].contents[2])
print(col[3].contents[2])
print(col[4].contents[0])
# Out:
# Wissam BEN YEDDER
#
# AS MONACO
#
# FRA
#
# 16

# %%
row = {}
row[table_head[0].contents[0]] = col[0].contents[0]
row[table_head[1].contents[0]] = col[1].contents[2]
row[table_head[2].contents[0]] = col[2].contents[2]
row[table_head[3].contents[0]] = col[3].contents[2]
row[table_head[4].contents[0]] = col[4].contents[0]
print(row)
# Out:
# {'POSITION': '1', 'Joueur': '\r\nWissam BEN YEDDER                                                        ', 'Club': '\r\nAS MONACO                                                        ', 'Nationalité': '\r\nFRA                                                        ', 'Buts': '\r\n16                                                        '}

# %%
def create_row(position):
    row = {}
    col =  li_tags[position].find_all('div')
    row[table_head[0].contents[0]] = col[0].contents[0]
    row[table_head[1].contents[0]] = col[1].contents[2].replace('\r\n','').strip()
    row[table_head[2].contents[0]] = col[2].contents[2].replace('\r\n','').strip()
    row[table_head[3].contents[0]] = col[3].contents[2].replace('\r\n','').strip()
    row[table_head[4].contents[0]] = col[4].contents[0].replace('\r\n','').strip()
    print(row)
    return row
rows = []    
for n in range(50):
    rows.append(create_row(n))
# Out:
# {'POSITION': '1', 'Joueur': 'Wissam BEN YEDDER                                                        ', 'Club': 'AS MONACO                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '16                                                        '}
# {'POSITION': '2', 'Joueur': 'Kylian MBAPPE                                                        ', 'Club': 'PARIS SAINT-GERMAIN                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '15                                                        '}
# {'POSITION': '3', 'Joueur': 'Moussa DEMBELE                                                        ', 'Club': 'OLYMPIQUE LYONNAIS                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '13                                                        '}
# {'POSITION': '4', 'Joueur': 'NEYMAR JR                                                        ', 'Club': 'PARIS SAINT-GERMAIN                                                        ', 'Nationalité': 'BRE                                                        ', 'Buts': '13                                                        '}
# {'POSITION': '5', 'Joueur': 'Habib DIALLO                                                        ', 'Club': 'FC METZ                                                        ', 'Nationalité': 'SEN                                                        ', 'Buts': '12                                                        '}
# {'POSITION': '6', 'Joueur': 'Victor OSIMHEN                                                        ', 'Club': 'LOSC LILLE                                                        ', 'Nationalité': 'NIG                                                        ', 'Buts': '12                                                        '}
# {'POSITION': '7', 'Joueur': 'Mauro ICARDI                                                        ', 'Club': 'PARIS SAINT-GERMAIN                                                        ', 'Nationalité': 'ARG                                                        ', 'Buts': '10                                                        '}
# {'POSITION': '8', 'Joueur': 'Andy DELORT                                                        ', 'Club': 'MONTPELLIER HÉRAULT SC                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '9                                                        '}
# {'POSITION': '9', 'Joueur': 'Memphis DEPAY                                                        ', 'Club': 'OLYMPIQUE LYONNAIS                                                        ', 'Nationalité': 'HOL                                                        ', 'Buts': '9                                                        '}
# {'POSITION': '10', 'Joueur': 'Adrien THOMASSON                                                        ', 'Club': 'RC STRASBOURG ALSACE                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '8                                                        '}
# {'POSITION': '11', 'Joueur': 'Kasper DOLBERG                                                        ', 'Club': 'OGC NICE                                                        ', 'Nationalité': 'DAN                                                        ', 'Buts': '8                                                        '}
# {'POSITION': '12', 'Joueur': "M'Baye NIANG                                                        ", 'Club': 'STADE RENNAIS FC                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '8                                                        '}
# {'POSITION': '13', 'Joueur': 'Angel DI MARIA                                                        ', 'Club': 'PARIS SAINT-GERMAIN                                                        ', 'Nationalité': 'ARG                                                        ', 'Buts': '8                                                        '}
# {'POSITION': '14', 'Joueur': 'Islam SLIMANI                                                        ', 'Club': 'AS MONACO                                                        ', 'Nationalité': 'ALG                                                        ', 'Buts': '8                                                        '}
# {'POSITION': '15', 'Joueur': 'Ludovic AJORQUE                                                        ', 'Club': 'RC STRASBOURG ALSACE                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '8                                                        '}
# {'POSITION': '16', 'Joueur': 'Dimitri PAYET                                                        ', 'Club': 'OLYMPIQUE DE MARSEILLE                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '8                                                        '}
# {'POSITION': '17', 'Joueur': 'Dario BENEDETTO                                                        ', 'Club': 'OLYMPIQUE DE MARSEILLE                                                        ', 'Nationalité': 'ARG                                                        ', 'Buts': '7                                                        '}
# {'POSITION': '18', 'Joueur': 'Denis BOUANGA                                                        ', 'Club': 'AS SAINT-ÉTIENNE                                                        ', 'Nationalité': 'GAB                                                        ', 'Buts': '7                                                        '}
# {'POSITION': '19', 'Joueur': 'Wylan CYPRIEN                                                        ', 'Club': 'OGC NICE                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '7                                                        '}
# {'POSITION': '20', 'Joueur': 'Florent MOLLET                                                        ', 'Club': 'MONTPELLIER HÉRAULT SC                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '6                                                        '}
# {'POSITION': '21', 'Joueur': 'Boulaye DIA                                                        ', 'Club': 'STADE DE REIMS                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '6                                                        '}
# {'POSITION': '22', 'Joueur': 'Romain HAMOUMA                                                        ', 'Club': 'AS SAINT-ÉTIENNE                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '6                                                        '}
# {'POSITION': '23', 'Joueur': 'Rachid ALIOUI                                                        ', 'Club': 'ANGERS SCO                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '6                                                        '}
# {'POSITION': '24', 'Joueur': 'Adrien HUNOU                                                        ', 'Club': 'STADE RENNAIS FC                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '6                                                        '}
# {'POSITION': '25', 'Joueur': 'Jimmy BRIAND                                                        ', 'Club': 'FC GIRONDINS DE BORDEAUX                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '6                                                        '}
# {'POSITION': '26', 'Joueur': 'Serhou GUIRASSY                                                        ', 'Club': 'AMIENS SC                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '6                                                        '}
# {'POSITION': '27', 'Joueur': 'Moses SIMON                                                        ', 'Club': 'FC NANTES                                                        ', 'Nationalité': 'NIG                                                        ', 'Buts': '5                                                        '}
# {'POSITION': '28', 'Joueur': 'Gaëtan LABORDE                                                        ', 'Club': 'MONTPELLIER HÉRAULT SC                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '5                                                        '}
# {'POSITION': '29', 'Joueur': 'Irvin CARDONA                                                        ', 'Club': 'STADE BRESTOIS 29                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '5                                                        '}
# {'POSITION': '30', 'Joueur': 'Romain PHILIPPOTEAUX                                                        ', 'Club': 'NÎMES OLYMPIQUE                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '5                                                        '}
# {'POSITION': '31', 'Joueur': 'Mama BALDE                                                        ', 'Club': 'DIJON FCO                                                        ', 'Nationalité': 'POR                                                        ', 'Buts': '5                                                        '}
# {'POSITION': '32', 'Joueur': 'Josh MAJA                                                        ', 'Club': 'FC GIRONDINS DE BORDEAUX                                                        ', 'Nationalité': 'NIG                                                        ', 'Buts': '5                                                        '}
# {'POSITION': '33', 'Joueur': 'Nemanja RADONJIC                                                        ', 'Club': 'OLYMPIQUE DE MARSEILLE                                                        ', 'Nationalité': 'SER                                                        ', 'Buts': '5                                                        '}
# {'POSITION': '34', 'Joueur': 'Ludovic BLAS                                                        ', 'Club': 'FC NANTES                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '5                                                        '}
# {'POSITION': '35', 'Joueur': 'Steven MENDOZA                                                        ', 'Club': 'AMIENS SC                                                        ', 'Nationalité': 'COL                                                        ', 'Buts': '5                                                        '}
# {'POSITION': '36', 'Joueur': 'Stephy MAVIDIDI                                                        ', 'Club': 'DIJON FCO                                                        ', 'Nationalité': 'ANG                                                        ', 'Buts': '5                                                        '}
# {'POSITION': '37', 'Joueur': 'Nicolas DE PREVILLE                                                        ', 'Club': 'FC GIRONDINS DE BORDEAUX                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '5                                                        '}
# {'POSITION': '38', 'Joueur': 'RAPHINHA                                                        ', 'Club': 'STADE RENNAIS FC                                                        ', 'Nationalité': 'BRE                                                        ', 'Buts': '5                                                        '}
# {'POSITION': '39', 'Joueur': 'Julio TAVARES                                                        ', 'Club': 'DIJON FCO                                                        ', 'Nationalité': 'CAP                                                        ', 'Buts': '5                                                        '}
# {'POSITION': '40', 'Joueur': 'Pierre LEES-MELOU                                                        ', 'Club': 'OGC NICE                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '4                                                        '}
# {'POSITION': '41', 'Joueur': 'Keita BALDE                                                        ', 'Club': 'AS MONACO                                                        ', 'Nationalité': 'SEN                                                        ', 'Buts': '4                                                        '}
# {'POSITION': '42', 'Joueur': 'Maxwel CORNET                                                        ', 'Club': 'OLYMPIQUE LYONNAIS                                                        ', 'Nationalité': 'IVO                                                        ', 'Buts': '4                                                        '}
# {'POSITION': '43', 'Joueur': 'Ui-Jo HWANG                                                        ', 'Club': 'FC GIRONDINS DE BORDEAUX                                                        ', 'Nationalité': 'CSU                                                        ', 'Buts': '4                                                        '}
# {'POSITION': '44', 'Joueur': 'Rémi OUDIN                                                        ', 'Club': 'FC GIRONDINS DE BORDEAUX                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '4                                                        '}
# {'POSITION': '45', 'Joueur': 'Opa NGUETTE                                                        ', 'Club': 'FC METZ                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '4                                                        '}
# {'POSITION': '46', 'Joueur': 'Efthymios KOULOURIS                                                        ', 'Club': 'TOULOUSE FC                                                        ', 'Nationalité': 'GRE                                                        ', 'Buts': '4                                                        '}
# {'POSITION': '47', 'Joueur': 'Gelson MARTINS                                                        ', 'Club': 'AS MONACO                                                        ', 'Nationalité': 'POR                                                        ', 'Buts': '4                                                        '}
# {'POSITION': '48', 'Joueur': 'Loïc REMY                                                        ', 'Club': 'LOSC LILLE                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '4                                                        '}
# {'POSITION': '49', 'Joueur': 'Kalifa COULIBALY                                                        ', 'Club': 'FC NANTES                                                        ', 'Nationalité': 'MAI                                                        ', 'Buts': '4                                                        '}
# {'POSITION': '50', 'Joueur': 'Téji SAVANIER                                                        ', 'Club': 'MONTPELLIER HÉRAULT SC                                                        ', 'Nationalité': 'FRA                                                        ', 'Buts': '4                                                        '}

# %%
import pandas as pd

df  = pd.DataFrame.from_dict(rows)
df
# Out:
#    POSITION                                             Joueur  \
# 0         1  Wissam BEN YEDDER                             ...
# 1         2  Kylian MBAPPE                                 ...
# 2         3  Moussa DEMBELE                                ...
# 3         4  NEYMAR JR                                     ...
# 4         5  Habib DIALLO                                  ...
# 5         6  Victor OSIMHEN                                ...
# 6         7  Mauro ICARDI                                  ...
# 7         8  Andy DELORT                                   ...
# 8         9  Memphis DEPAY                                 ...
# 9        10  Adrien THOMASSON                              ...
# 10       11  Kasper DOLBERG                                ...
# 11       12  M'Baye NIANG                                  ...
# 12       13  Angel DI MARIA                                ...
# 13       14  Islam SLIMANI                                 ...
# 14       15  Ludovic AJORQUE                               ...
# 15       16  Dimitri PAYET                                 ...
# 16       17  Dario BENEDETTO                               ...
# 17       18  Denis BOUANGA                                 ...
# 18       19  Wylan CYPRIEN                                 ...
# 19       20  Florent MOLLET                                ...
# 20       21  Boulaye DIA                                   ...
# 21       22  Romain HAMOUMA                                ...
# 22       23  Rachid ALIOUI                                 ...
# 23       24  Adrien HUNOU                                  ...
# 24       25  Jimmy BRIAND                                  ...
# 25       26  Serhou GUIRASSY                               ...
# 26       27  Moses SIMON                                   ...
# 27       28  Gaëtan LABORDE                                ...
# 28       29  Irvin CARDONA                                 ...
# 29       30  Romain PHILIPPOTEAUX                          ...
# 30       31  Mama BALDE                                    ...
# 31       32  Josh MAJA                                     ...
# 32       33  Nemanja RADONJIC                              ...
# 33       34  Ludovic BLAS                                  ...
# 34       35  Steven MENDOZA                                ...
# 35       36  Stephy MAVIDIDI                               ...
# 36       37  Nicolas DE PREVILLE                           ...
# 37       38  RAPHINHA                                      ...
# 38       39  Julio TAVARES                                 ...
# 39       40  Pierre LEES-MELOU                             ...
# 40       41  Keita BALDE                                   ...
# 41       42  Maxwel CORNET                                 ...
# 42       43  Ui-Jo HWANG                                   ...
# 43       44  Rémi OUDIN                                    ...
# 44       45  Opa NGUETTE                                   ...
# 45       46  Efthymios KOULOURIS                           ...
# 46       47  Gelson MARTINS                                ...
# 47       48  Loïc REMY                                     ...
# 48       49  Kalifa COULIBALY                              ...
# 49       50  Téji SAVANIER                                 ...
#
#                                                  Club  \
# 0   AS MONACO                                     ...
# 1   PARIS SAINT-GERMAIN                           ...
# 2   OLYMPIQUE LYONNAIS                            ...
# 3   PARIS SAINT-GERMAIN                           ...
# 4   FC METZ                                       ...
# 5   LOSC LILLE                                    ...
# 6   PARIS SAINT-GERMAIN                           ...
# 7   MONTPELLIER HÉRAULT SC                        ...
# 8   OLYMPIQUE LYONNAIS                            ...
# 9   RC STRASBOURG ALSACE                          ...
# 10  OGC NICE                                      ...
# 11  STADE RENNAIS FC                              ...
# 12  PARIS SAINT-GERMAIN                           ...
# 13  AS MONACO                                     ...
# 14  RC STRASBOURG ALSACE                          ...
# 15  OLYMPIQUE DE MARSEILLE                        ...
# 16  OLYMPIQUE DE MARSEILLE                        ...
# 17  AS SAINT-ÉTIENNE                              ...
# 18  OGC NICE                                      ...
# 19  MONTPELLIER HÉRAULT SC                        ...
# 20  STADE DE REIMS                                ...
# 21  AS SAINT-ÉTIENNE                              ...
# 22  ANGERS SCO                                    ...
# 23  STADE RENNAIS FC                              ...
# 24  FC GIRONDINS DE BORDEAUX                      ...
# 25  AMIENS SC                                     ...
# 26  FC NANTES                                     ...
# 27  MONTPELLIER HÉRAULT SC                        ...
# 28  STADE BRESTOIS 29                             ...
# 29  NÎMES OLYMPIQUE                               ...
# 30  DIJON FCO                                     ...
# 31  FC GIRONDINS DE BORDEAUX                      ...
# 32  OLYMPIQUE DE MARSEILLE                        ...
# 33  FC NANTES                                     ...
# 34  AMIENS SC                                     ...
# 35  DIJON FCO                                     ...
# 36  FC GIRONDINS DE BORDEAUX                      ...
# 37  STADE RENNAIS FC                              ...
# 38  DIJON FCO                                     ...
# 39  OGC NICE                                      ...
# 40  AS MONACO                                     ...
# 41  OLYMPIQUE LYONNAIS                            ...
# 42  FC GIRONDINS DE BORDEAUX                      ...
# 43  FC GIRONDINS DE BORDEAUX                      ...
# 44  FC METZ                                       ...
# 45  TOULOUSE FC                                   ...
# 46  AS MONACO                                     ...
# 47  LOSC LILLE                                    ...
# 48  FC NANTES                                     ...
# 49  MONTPELLIER HÉRAULT SC                        ...
#
#                                           Nationalité  \
# 0   FRA                                           ...
# 1   FRA                                           ...
# 2   FRA                                           ...
# 3   BRE                                           ...
# 4   SEN                                           ...
# 5   NIG                                           ...
# 6   ARG                                           ...
# 7   FRA                                           ...
# 8   HOL                                           ...
# 9   FRA                                           ...
# 10  DAN                                           ...
# 11  FRA                                           ...
# 12  ARG                                           ...
# 13  ALG                                           ...
# 14  FRA                                           ...
# 15  FRA                                           ...
# 16  ARG                                           ...
# 17  GAB                                           ...
# 18  FRA                                           ...
# 19  FRA                                           ...
# 20  FRA                                           ...
# 21  FRA                                           ...
# 22  FRA                                           ...
# 23  FRA                                           ...
# 24  FRA                                           ...
# 25  FRA                                           ...
# 26  NIG                                           ...
# 27  FRA                                           ...
# 28  FRA                                           ...
# 29  FRA                                           ...
# 30  POR                                           ...
# 31  NIG                                           ...
# 32  SER                                           ...
# 33  FRA                                           ...
# 34  COL                                           ...
# 35  ANG                                           ...
# 36  FRA                                           ...
# 37  BRE                                           ...
# 38  CAP                                           ...
# 39  FRA                                           ...
# 40  SEN                                           ...
# 41  IVO                                           ...
# 42  CSU                                           ...
# 43  FRA                                           ...
# 44  FRA                                           ...
# 45  GRE                                           ...
# 46  POR                                           ...
# 47  FRA                                           ...
# 48  MAI                                           ...
# 49  FRA                                           ...
#
#                                                  Buts
# 0   16                                            ...
# 1   15                                            ...
# 2   13                                            ...
# 3   13                                            ...
# 4   12                                            ...
# 5   12                                            ...
# 6   10                                            ...
# 7   9                                             ...
# 8   9                                             ...
# 9   8                                             ...
# 10  8                                             ...
# 11  8                                             ...
# 12  8                                             ...
# 13  8                                             ...
# 14  8                                             ...
# 15  8                                             ...
# 16  7                                             ...
# 17  7                                             ...
# 18  7                                             ...
# 19  6                                             ...
# 20  6                                             ...
# 21  6                                             ...
# 22  6                                             ...
# 23  6                                             ...
# 24  6                                             ...
# 25  6                                             ...
# 26  5                                             ...
# 27  5                                             ...
# 28  5                                             ...
# 29  5                                             ...
# 30  5                                             ...
# 31  5                                             ...
# 32  5                                             ...
# 33  5                                             ...
# 34  5                                             ...
# 35  5                                             ...
# 36  5                                             ...
# 37  5                                             ...
# 38  5                                             ...
# 39  4                                             ...
# 40  4                                             ...
# 41  4                                             ...
# 42  4                                             ...
# 43  4                                             ...
# 44  4                                             ...
# 45  4                                             ...
# 46  4                                             ...
# 47  4                                             ...
# 48  4                                             ...
# 49  4                                             ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
# POSITION       50 non-null object
# Joueur         50 non-null object
# Club           50 non-null object
# Nationalité    50 non-null object
# Buts           50 non-null object
# dtypes: object(5)
# memory usage: 1.0+ KB

# %%
df.iloc[:,4]=df.iloc[:,4].astype('int') 
#type(df.iloc[0,1])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
# POSITION       50 non-null object
# Joueur         50 non-null object
# Club           50 non-null object
# Nationalité    50 non-null object
# Buts           50 non-null int32
# dtypes: int32(1), object(4)
# memory usage: 1.0+ KB

# %%
df.set_index('POSITION', drop=True, inplace=True)
df
# Out:
#                                                      Joueur  \
# POSITION
# 1         Wissam BEN YEDDER                             ...
# 2         Kylian MBAPPE                                 ...
# 3         Moussa DEMBELE                                ...
# 4         NEYMAR JR                                     ...
# 5         Habib DIALLO                                  ...
# 6         Victor OSIMHEN                                ...
# 7         Mauro ICARDI                                  ...
# 8         Andy DELORT                                   ...
# 9         Memphis DEPAY                                 ...
# 10        Adrien THOMASSON                              ...
# 11        Kasper DOLBERG                                ...
# 12        M'Baye NIANG                                  ...
# 13        Angel DI MARIA                                ...
# 14        Islam SLIMANI                                 ...
# 15        Ludovic AJORQUE                               ...
# 16        Dimitri PAYET                                 ...
# 17        Dario BENEDETTO                               ...
# 18        Denis BOUANGA                                 ...
# 19        Wylan CYPRIEN                                 ...
# 20        Florent MOLLET                                ...
# 21        Boulaye DIA                                   ...
# 22        Romain HAMOUMA                                ...
# 23        Rachid ALIOUI                                 ...
# 24        Adrien HUNOU                                  ...
# 25        Jimmy BRIAND                                  ...
# 26        Serhou GUIRASSY                               ...
# 27        Moses SIMON                                   ...
# 28        Gaëtan LABORDE                                ...
# 29        Irvin CARDONA                                 ...
# 30        Romain PHILIPPOTEAUX                          ...
# 31        Mama BALDE                                    ...
# 32        Josh MAJA                                     ...
# 33        Nemanja RADONJIC                              ...
# 34        Ludovic BLAS                                  ...
# 35        Steven MENDOZA                                ...
# 36        Stephy MAVIDIDI                               ...
# 37        Nicolas DE PREVILLE                           ...
# 38        RAPHINHA                                      ...
# 39        Julio TAVARES                                 ...
# 40        Pierre LEES-MELOU                             ...
# 41        Keita BALDE                                   ...
# 42        Maxwel CORNET                                 ...
# 43        Ui-Jo HWANG                                   ...
# 44        Rémi OUDIN                                    ...
# 45        Opa NGUETTE                                   ...
# 46        Efthymios KOULOURIS                           ...
# 47        Gelson MARTINS                                ...
# 48        Loïc REMY                                     ...
# 49        Kalifa COULIBALY                              ...
# 50        Téji SAVANIER                                 ...
#
#                                                        Club  \
# POSITION
# 1         AS MONACO                                     ...
# 2         PARIS SAINT-GERMAIN                           ...
# 3         OLYMPIQUE LYONNAIS                            ...
# 4         PARIS SAINT-GERMAIN                           ...
# 5         FC METZ                                       ...
# 6         LOSC LILLE                                    ...
# 7         PARIS SAINT-GERMAIN                           ...
# 8         MONTPELLIER HÉRAULT SC                        ...
# 9         OLYMPIQUE LYONNAIS                            ...
# 10        RC STRASBOURG ALSACE                          ...
# 11        OGC NICE                                      ...
# 12        STADE RENNAIS FC                              ...
# 13        PARIS SAINT-GERMAIN                           ...
# 14        AS MONACO                                     ...
# 15        RC STRASBOURG ALSACE                          ...
# 16        OLYMPIQUE DE MARSEILLE                        ...
# 17        OLYMPIQUE DE MARSEILLE                        ...
# 18        AS SAINT-ÉTIENNE                              ...
# 19        OGC NICE                                      ...
# 20        MONTPELLIER HÉRAULT SC                        ...
# 21        STADE DE REIMS                                ...
# 22        AS SAINT-ÉTIENNE                              ...
# 23        ANGERS SCO                                    ...
# 24        STADE RENNAIS FC                              ...
# 25        FC GIRONDINS DE BORDEAUX                      ...
# 26        AMIENS SC                                     ...
# 27        FC NANTES                                     ...
# 28        MONTPELLIER HÉRAULT SC                        ...
# 29        STADE BRESTOIS 29                             ...
# 30        NÎMES OLYMPIQUE                               ...
# 31        DIJON FCO                                     ...
# 32        FC GIRONDINS DE BORDEAUX                      ...
# 33        OLYMPIQUE DE MARSEILLE                        ...
# 34        FC NANTES                                     ...
# 35        AMIENS SC                                     ...
# 36        DIJON FCO                                     ...
# 37        FC GIRONDINS DE BORDEAUX                      ...
# 38        STADE RENNAIS FC                              ...
# 39        DIJON FCO                                     ...
# 40        OGC NICE                                      ...
# 41        AS MONACO                                     ...
# 42        OLYMPIQUE LYONNAIS                            ...
# 43        FC GIRONDINS DE BORDEAUX                      ...
# 44        FC GIRONDINS DE BORDEAUX                      ...
# 45        FC METZ                                       ...
# 46        TOULOUSE FC                                   ...
# 47        AS MONACO                                     ...
# 48        LOSC LILLE                                    ...
# 49        FC NANTES                                     ...
# 50        MONTPELLIER HÉRAULT SC                        ...
#
#                                                 Nationalité  Buts
# POSITION
# 1         FRA                                           ...    16
# 2         FRA                                           ...    15
# 3         FRA                                           ...    13
# 4         BRE                                           ...    13
# 5         SEN                                           ...    12
# 6         NIG                                           ...    12
# 7         ARG                                           ...    10
# 8         FRA                                           ...     9
# 9         HOL                                           ...     9
# 10        FRA                                           ...     8
# 11        DAN                                           ...     8
# 12        FRA                                           ...     8
# 13        ARG                                           ...     8
# 14        ALG                                           ...     8
# 15        FRA                                           ...     8
# 16        FRA                                           ...     8
# 17        ARG                                           ...     7
# 18        GAB                                           ...     7
# 19        FRA                                           ...     7
# 20        FRA                                           ...     6
# 21        FRA                                           ...     6
# 22        FRA                                           ...     6
# 23        FRA                                           ...     6
# 24        FRA                                           ...     6
# 25        FRA                                           ...     6
# 26        FRA                                           ...     6
# 27        NIG                                           ...     5
# 28        FRA                                           ...     5
# 29        FRA                                           ...     5
# 30        FRA                                           ...     5
# 31        POR                                           ...     5
# 32        NIG                                           ...     5
# 33        SER                                           ...     5
# 34        FRA                                           ...     5
# 35        COL                                           ...     5
# 36        ANG                                           ...     5
# 37        FRA                                           ...     5
# 38        BRE                                           ...     5
# 39        CAP                                           ...     5
# 40        FRA                                           ...     4
# 41        SEN                                           ...     4
# 42        IVO                                           ...     4
# 43        CSU                                           ...     4
# 44        FRA                                           ...     4
# 45        FRA                                           ...     4
# 46        GRE                                           ...     4
# 47        POR                                           ...     4
# 48        FRA                                           ...     4
# 49        MAI                                           ...     4
# 50        FRA                                           ...     4

# %%
df.to_csv('ligue1_2020_buteurs.txt', sep = ',')

# %%
df.describe()
# Out:
#             Buts
# count  50.000000
# mean    6.740000
# std     3.015673
# min     4.000000
# 25%     5.000000
# 50%     6.000000
# 75%     8.000000
# max    16.000000

# %%
def moyVar(X):
    n = len(X)
    if n==0:
        return None
    else:
        s1, s2 = 0, 0
        for x in X:
            s1 = s1 + x
            s2 = s2 + x*x
        m = s1/n
        return m,s2/n - m**2

def moyVarP(X, N):
    p1, p2 = len(X), len(N)
    if p1==0 or p2 != p1:
        return None
    else:
        s1, s2, n = 0, 0, 0
        for k in range(1,p1):
            n = n + N[k]
            z = N[k]*X[k]
            s1 = s1 + z
            s2 = s2 + z*X[k]
        m = s1/n
        return m,s2/n - m**2

# %%
moyenne,variance=moyVar(df.Buts)

print(df[df.Buts>moyenne])
# Out:
#                                                      Joueur  \
# POSITION
# 1         Wissam BEN YEDDER                             ...
# 2         Kylian MBAPPE                                 ...
# 3         Moussa DEMBELE                                ...
# 4         NEYMAR JR                                     ...
# 5         Habib DIALLO                                  ...
# 6         Victor OSIMHEN                                ...
# 7         Mauro ICARDI                                  ...
# 8         Andy DELORT                                   ...
# 9         Memphis DEPAY                                 ...
# 10        Adrien THOMASSON                              ...
# 11        Kasper DOLBERG                                ...
# 12        M'Baye NIANG                                  ...
# 13        Angel DI MARIA                                ...
# 14        Islam SLIMANI                                 ...
# 15        Ludovic AJORQUE                               ...
# 16        Dimitri PAYET                                 ...
# 17        Dario BENEDETTO                               ...
# 18        Denis BOUANGA                                 ...
# 19        Wylan CYPRIEN                                 ...
#
#                                                        Club  \
# POSITION
# 1         AS MONACO                                     ...
# 2         PARIS SAINT-GERMAIN                           ...
# 3         OLYMPIQUE LYONNAIS                            ...
# 4         PARIS SAINT-GERMAIN                           ...
# 5         FC METZ                                       ...
# 6         LOSC LILLE                                    ...
# 7         PARIS SAINT-GERMAIN                           ...
# 8         MONTPELLIER HÉRAULT SC                        ...
# 9         OLYMPIQUE LYONNAIS                            ...
# 10        RC STRASBOURG ALSACE                          ...
# 11        OGC NICE                                      ...
# 12        STADE RENNAIS FC                              ...
# 13        PARIS SAINT-GERMAIN                           ...
# 14        AS MONACO                                     ...
# 15        RC STRASBOURG ALSACE                          ...
# 16        OLYMPIQUE DE MARSEILLE                        ...
# 17        OLYMPIQUE DE MARSEILLE                        ...
# 18        AS SAINT-ÉTIENNE                              ...
# 19        OGC NICE                                      ...
#
#                                                 Nationalité  Buts
# POSITION
# 1         FRA                                           ...    16
# 2         FRA                                           ...    15
# 3         FRA                                           ...    13
# 4         BRE                                           ...    13
# 5         SEN                                           ...    12
# 6         NIG                                           ...    12
# 7         ARG                                           ...    10
# 8         FRA                                           ...     9
# 9         HOL                                           ...     9
# 10        FRA                                           ...     8
# 11        DAN                                           ...     8
# 12        FRA                                           ...     8
# 13        ARG                                           ...     8
# 14        ALG                                           ...     8
# 15        FRA                                           ...     8
# 16        FRA                                           ...     8
# 17        ARG                                           ...     7
# 18        GAB                                           ...     7
# 19        FRA                                           ...     7

# %%
import numpy as np
import matplotlib.pyplot as plt
l = len(df)
x = np.arange(l)
y = df.Buts
plt.plot(x,y)
plt.plot(x,np.ones(l)*moyenne)
plt.plot(x,np.ones(l)*variance)
plt.show()
